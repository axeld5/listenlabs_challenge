# %%
import requests
from typing import Dict, Any, Optional

BASE_URL = "https://berghain.challenges.listenlabs.ai/"  # ← replace with the real host
PLAYER_ID = "5d7389b8-683e-453b-a35f-6d21b1b5e94e"
SCENARIO = 2  # choose 1, 2, or 3

def create_new_game(scenario: int, player_id: str) -> Dict[str, Any]:
    url = f"{BASE_URL}/new-game"
    res = requests.get(url, params={"scenario": scenario, "playerId": player_id}, timeout=30)
    res.raise_for_status()
    data = res.json()
    print("New game:", data["gameId"])
    return data

# %%
new_game = create_new_game(SCENARIO, PLAYER_ID)
game_id = new_game["gameId"]
constraints = new_game.get("constraints", [])
stats = new_game.get("attributeStatistics", {})
print(constraints)
print(stats)
# Out:
# New game: f7f1690a-b41c-41a1-a8e8-589607b99340
# [{'attribute': 'techno_lover', 'minCount': 650}, {'attribute': 'well_connected', 'minCount': 450}, {'attribute': 'creative', 'minCount': 300}, {'attribute': 'berlin_local', 'minCount': 750}]
# {'relativeFrequencies': {'techno_lover': 0.6265000000000001, 'well_connected': 0.4700000000000001, 'creative': 0.06227, 'berlin_local': 0.398}, 'correlations': {'techno_lover': {'techno_lover': 1, 'well_connected': -0.4696169332674324, 'creative': 0.09463317039891586, 'berlin_local': -0.6549403815606182}, 'well_connected': {'techno_lover': -0.4696169332674324, 'well_connected': 1, 'creative': 0.14197259140471485, 'berlin_local': 0.5724067808436452}, 'creative': {'techno_lover': 0.09463317039891586, 'well_connected': 0.14197259140471485, 'creative': 1, 'berlin_local': 0.14446459505650772}, 'berlin_local': {'techno_lover': -0.6549403815606182, 'well_connected': 0.5724067808436452, 'creative': 0.14446459505650772, 'berlin_local': 1}}}

# %%
from dataclasses import dataclass
import math
import numpy as np
from typing import Optional, Tuple, Callable, Dict


# ----------------------------- Utilities ---------------------------------- #

def _ceil_int(x: float) -> int:
    return int(math.ceil(x))


def _clamp(x: float, lo: float, hi: float) -> float:
    return max(lo, min(hi, x))


def _norm_ppf(p: np.ndarray) -> np.ndarray:
    """Fast inverse CDF for standard normal (Acklam's approximation).

    Works for scalar or array-like `p` in (0, 1). Values are clipped to
    [1e-12, 1-1e-12] for numerical stability.
    """
    # Coefficients in rational approximations
    a = np.array([
        -3.969683028665376e+01,
         2.209460984245205e+02,
        -2.759285104469687e+02,
         1.383577518672690e+02,
        -3.066479806614716e+01,
         2.506628277459239e+00,
    ])
    b = np.array([
        -5.447609879822406e+01,
         1.615858368580409e+02,
        -1.556989798598866e+02,
         6.680131188771972e+01,
        -1.328068155288572e+01,
    ])
    c = np.array([
        -7.784894002430293e-03,
        -3.223964580411365e-01,
        -2.400758277161838e+00,
        -2.549732539343734e+00,
         4.374664141464968e+00,
         2.938163982698783e+00,
    ])
    d = np.array([
         7.784695709041462e-03,
         3.224671290700398e-01,
         2.445134137142996e+00,
         3.754408661907416e+00,
    ])

    p = np.asarray(p, dtype=float)
    p = np.clip(p, 1e-12, 1 - 1e-12)

    # Define break-points
    plow = 0.02425
    phigh = 1 - plow

    z = np.empty_like(p)

    # lower region
    mask = p < plow
    if np.any(mask):
        q = np.sqrt(-2 * np.log(p[mask]))
        z[mask] = (((((c[0]*q + c[1])*q + c[2])*q + c[3])*q + c[4])*q + c[5]) / \
                  ((((d[0]*q + d[1])*q + d[2])*q + d[3])*q + 1)
        z[mask] = -z[mask]

    # upper region
    mask = p > phigh
    if np.any(mask):
        q = np.sqrt(-2 * np.log(1 - p[mask]))
        z[mask] = (((((c[0]*q + c[1])*q + c[2])*q + c[3])*q + c[4])*q + c[5]) / \
                  ((((d[0]*q + d[1])*q + d[2])*q + d[3])*q + 1)

    # central region
    mask = (p >= plow) & (p <= phigh)
    if np.any(mask):
        q = p[mask] - 0.5
        r = q*q
        z[mask] = (((((a[0]*r + a[1])*r + a[2])*r + a[3])*r + a[4])*r + a[5]) * q / \
                  (((((b[0]*r + b[1])*r + b[2])*r + b[3])*r + b[4])*r + 1)

    return z


def _nearest_psd(corr: np.ndarray, eps: float = 1e-9) -> np.ndarray:
    """Project a symmetric matrix to the nearest positive semidefinite matrix
    by clipping negative eigenvalues, then renormalize diagonal to 1.
    """
    B = (corr + corr.T) / 2
    vals, vecs = np.linalg.eigh(B)
    vals = np.maximum(vals, eps)
    B_psd = (vecs * vals) @ vecs.T
    # Normalize to correlation (diag = 1)
    d = np.sqrt(np.clip(np.diag(B_psd), eps, None))
    B_corr = B_psd / d[:, None] / d[None, :]
    return (B_corr + B_corr.T) / 2


def build_correlation_from_cov(p: np.ndarray, cov: np.ndarray) -> np.ndarray:
    """Convert Bernoulli covariance to correlation matrix, then project to PSD.

    cov_ij = Corr_ij * sqrt(p_i(1-p_i) p_j(1-p_j))
    => Corr_ij = cov_ij / sqrt(var_i var_j)
    """
    p = np.asarray(p, dtype=float)
    var = p * (1 - p)
    denom = np.sqrt(np.maximum(var, 1e-12))
    corr = cov / (denom[:, None] * denom[None, :])
    # Clamp numerical range and set diag to 1
    np.fill_diagonal(corr, 1.0)
    corr = np.clip(corr, -0.999, 0.999)
    return _nearest_psd(corr)


class ArrivalSampler:
    """Sampler for future arrivals.

    If `corr` is provided, use a Gaussian copula with the given correlation
    matrix to couple attributes; otherwise sample attributes independently.
    """
    def __init__(self, p: np.ndarray, corr: Optional[np.ndarray] = None, seed: Optional[int] = None):
        self.p = np.asarray(p, dtype=float)
        self.m = self.p.size
        self.rng = np.random.default_rng(seed)
        self.use_copula = corr is not None
        if self.use_copula:
            corr = np.asarray(corr, dtype=float)
            # Project to PSD & ensure correlation-like properties
            self.corr = _nearest_psd(corr)
            self.thresholds = _norm_ppf(self.p)
            # Cholesky may still fail if near-singular; fall back to eigh
            try:
                self.L = np.linalg.cholesky(self.corr)
                self._mvnorm = self._mvnorm_chol
            except np.linalg.LinAlgError:
                vals, vecs = np.linalg.eigh(self.corr)
                vals = np.clip(vals, 0.0, None)
                self.L_ev = vecs @ np.diag(np.sqrt(vals))
                self._mvnorm = self._mvnorm_eig
        else:
            self.corr = None

    def _mvnorm_chol(self, n: int = 1) -> np.ndarray:
        z = self.rng.standard_normal(size=(n, self.m))
        return z @ self.L.T

    def _mvnorm_eig(self, n: int = 1) -> np.ndarray:
        z = self.rng.standard_normal(size=(n, self.m))
        return z @ self.L_ev.T

    def sample(self, n: int = 1) -> np.ndarray:
        if not self.use_copula:
            # independent Bernoulli
            u = self.rng.random(size=(n, self.m))
            return (u < self.p).astype(np.int8)
        else:
            z = self._mvnorm(n)
            # Dichotomize at per-dimension thresholds to get Bernoulli
            return (z <= self.thresholds).astype(np.int8)


# --------------------------- Solver classes -------------------------------- #

@dataclass
class SolverConfig:
    alphas: np.ndarray            # shape (m,)
    p: np.ndarray                 # shape (m,), P(x_k=1)
    N: int = 1000                 # total acceptances target
    reject_budget: int = 20000    # max rejections allowed (stopping condition in sim)
    # If you pass `cov` we convert it to correlation; if you have `corr` already
    # you can pass it directly and leave cov=None.
    cov: Optional[np.ndarray] = None    # shape (m,m) Bernoulli covariance
    corr: Optional[np.ndarray] = None   # shape (m,m) Pearson correlation
    risk_tolerance: float = 0.01        # max failure prob in rollout (chance constraint)
    sims: int = 0                       # 0 => deterministic-only; >0 enables rollout lookahead
    seed: Optional[int] = None


class OnlineQuotaSolver:
    def __init__(self, cfg: SolverConfig):
        self.cfg = cfg
        self.m = int(cfg.alphas.size)
        self.alphas = np.asarray(cfg.alphas, dtype=float)
        assert np.all((self.alphas >= 0) & (self.alphas <= 1)), "alphas must be in [0,1]"
        self.p = np.asarray(cfg.p, dtype=float)
        assert self.p.size == self.m, "p and alphas must have same length"
        assert np.all((self.p > 0) & (self.p < 1)), "p must be strictly between 0 and 1 for all dims"
        if cfg.corr is not None:
            corr = np.asarray(cfg.corr, dtype=float)
        elif cfg.cov is not None:
            corr = build_correlation_from_cov(self.p, np.asarray(cfg.cov, dtype=float))
        else:
            corr = None
        self.sampler = ArrivalSampler(self.p, corr=corr, seed=cfg.seed)
        # Targets
        self.N = int(cfg.N)
        self.reject_budget = int(cfg.reject_budget)
        self.t = np.array([_ceil_int(a * self.N) for a in self.alphas], dtype=int)
        self.reset()

    # ----------------------------- State ---------------------------------- #
    def reset(self):
        self.a = 0                        # accepted so far
        self.r = 0                        # rejected so far
        self.c = np.zeros(self.m, dtype=int)  # counts of ones among accepted

    @property
    def remaining_slots(self) -> int:
        return self.N - self.a

    @property
    def remaining_required(self) -> np.ndarray:
        # Remaining required ones to hit targets, lower-bounded by 0
        return np.maximum(self.t - self.c, 0)

    # --------------------------- Core logic -------------------------------- #
    def _feasible_if_accept(self, x: np.ndarray) -> Tuple[bool, np.ndarray]:
        """Check the deterministic necessary feasibility after accepting x.
        Returns (feasible, per-attribute slack_after_accept), where slack is
        (c + x + r' - t). Negative slack for any k means infeasible.
        """
        x = np.asarray(x, dtype=int)
        r_after = self.remaining_slots - 1
        slack = self.c + x + r_after - self.t
        feasible = bool(np.all(slack >= 0))
        return feasible, slack

    def _greedy_safe_accept(self, x: np.ndarray) -> bool:
        feasible, _ = self._feasible_if_accept(x)
        return feasible

    def decide(self, x: np.ndarray) -> Tuple[bool, Dict]:
        """Return (accept_bool, info_dict) for the current candidate x.

        If cfg.sims == 0: purely deterministic — accept iff accepting is
        deterministically feasible. This is *very* fast and already performs
        well when you have a large rejection budget.

        If cfg.sims > 0: run a one-step stochastic rollout to choose the
        branch (accept vs reject) with lower expected rejections subject to a
        max failure probability (chance constraint).
        """
        x = np.asarray(x, dtype=int)
        assert x.size == self.m and np.all((x == 0) | (x == 1)), "x must be a 0/1 vector of length m"

        # Fast guard: if no slots left, must reject
        if self.remaining_slots <= 0:
            return False, {"reason": "no_slots_left"}

        # Deterministic necessary condition
        feasible, slack = self._feasible_if_accept(x)
        if not feasible and self.cfg.sims == 0:
            return False, {"reason": "infeasible_if_accept", "slack": slack}
        if feasible and self.cfg.sims == 0:
            return True, {"reason": "deterministic_feasible", "slack": slack}

        # If using rollout, evaluate both branches
        # Early pruning: if infeasible to accept, only 'reject' branch is valid
        branches = ["accept", "reject"] if feasible else ["reject"]
        best_choice = None
        best_metric = None
        details = {}

        for br in branches:
            ok, success_rate, exp_rej = self._rollout_metric(x, branch=br, sims=self.cfg.sims)
            details[br] = {"success_rate": success_rate, "exp_future_rejections": exp_rej}
            if not ok:
                continue
            metric = exp_rej  # we minimize expected future rejections
            if best_metric is None or metric < best_metric:
                best_metric = metric
                best_choice = br

        if best_choice is None:
            # Neither branch met risk tolerance; fall back to deterministic guard
            return (feasible, {"reason": "fallback_deterministic", "slack": slack, "rollout": details})

        return (best_choice == "accept", {"reason": "rollout_choice", "rollout": details})

    def update(self, x: np.ndarray, accept: bool):
        x = np.asarray(x, dtype=int)
        if accept:
            assert self._feasible_if_accept(x)[0], "update called with infeasible accept; guard with decide() first"
            self.a += 1
            self.c += x
        else:
            self.r += 1

    # ---------------------------- Rollout ---------------------------------- #
    def _clone_state(self):
        return self.a, self.r, self.c.copy()

    def _restore_state(self, snapshot):
        self.a, self.r, self.c = snapshot[0], snapshot[1], snapshot[2]

    def _rollout_metric(self, x: np.ndarray, branch: str, sims: int) -> Tuple[bool, float, float]:
        """Simulate the remainder under the greedy-safe policy starting with
        either accepting or rejecting the current x. Returns:
            (ok, success_rate, expected_future_rejections)
        where `ok` is True if success_rate >= 1 - risk_tolerance.
        """
        assert branch in ("accept", "reject")
        successes = 0
        rejections_list = []
        snapshot = self._clone_state()

        for _ in range(sims):
            self._restore_state(snapshot)
            # Apply the branch decision
            if branch == "accept":
                if not self._feasible_if_accept(x)[0]:
                    # Immediate failure for this path
                    success = False
                    future_rej = 0
                    rejections_list.append(future_rej)
                    continue
                self.a += 1
                self.c += x
            else:
                self.r += 1

            # Simulate until we hit N or the reject budget (only matters if you
            # want to guard against exhausting allowed rejections)
            while self.a < self.N and self.r < self.reject_budget:
                y = self.sampler.sample(1)[0]
                if self._greedy_safe_accept(y):
                    self.a += 1
                    self.c += y
                else:
                    self.r += 1

            success = (self.a >= self.N) and np.all(self.c >= self.t)
            future_rej = max(0, self.r - snapshot[1] - (1 if branch == "reject" else 0))
            rejections_list.append(future_rej)
            if success:
                successes += 1

        self._restore_state(snapshot)
        success_rate = successes / sims if sims > 0 else 1.0
        exp_rej = float(np.mean(rejections_list)) if sims > 0 else 0.0
        ok = (success_rate >= 1 - self.cfg.risk_tolerance)
        return ok, success_rate, exp_rej

# %%
# Create the sampling-based solver
constraints_data = [
    {'attribute': 'techno_lover', 'minCount': 650}, 
    {'attribute': 'well_connected', 'minCount': 450}, 
    {'attribute': 'creative', 'minCount': 300}, 
    {'attribute': 'berlin_local', 'minCount': 750}
]

population_data = {
    'relativeFrequencies': {
        'techno_lover': 0.6265000000000001, 
        'well_connected': 0.4700000000000001, 
        'creative': 0.06227, 
        'berlin_local': 0.398
    }, 
    'correlations': {
        'techno_lover': {'techno_lover': 1, 'well_connected': -0.4696169332674324, 'creative': 0.09463317039891586, 'berlin_local': -0.6549403815606182}, 
        'well_connected': {'techno_lover': -0.4696169332674324, 'well_connected': 1, 'creative': 0.14197259140471485, 'berlin_local': 0.5724067808436452}, 
        'creative': {'techno_lover': 0.09463317039891586, 'well_connected': 0.14197259140471485, 'creative': 1, 'berlin_local': 0.14446459505650772}, 
        'berlin_local': {'techno_lover': -0.6549403815606182, 'well_connected': 0.5724067808436452, 'creative': 0.14446459505650772, 'berlin_local': 1}
    }
}

# Map attribute names to indices
attribute_names = ['techno_lover', 'well_connected', 'creative', 'berlin_local']
attr_name_to_idx = {name: idx for idx, name in enumerate(attribute_names)}

# Create population sampler
attribute_probs = np.array([
    population_data['relativeFrequencies']['techno_lover'],
    population_data['relativeFrequencies']['well_connected'],
    population_data['relativeFrequencies']['creative'],
    population_data['relativeFrequencies']['berlin_local']
])

# Build covariance matrix from correlations
correlations = population_data['correlations']
covariance_matrix = np.zeros((4, 4))
for i, attr1 in enumerate(attribute_names):
    for j, attr2 in enumerate(attribute_names):
        correlation = correlations[attr1][attr2]
        # Convert correlation to covariance using attribute probabilities
        std_i = np.sqrt(attribute_probs[i] * (1 - attribute_probs[i]))
        std_j = np.sqrt(attribute_probs[j] * (1 - attribute_probs[j]))
        covariance_matrix[i, j] = correlation * std_i * std_j


# Create constraints vector
t = np.array([
    constraints_data[0]['minCount']/1000,  # techno_lover: 650
    constraints_data[1]['minCount']/1000,  # well_connected: 450
    constraints_data[2]['minCount']/1000,  # creative: 300
    constraints_data[3]['minCount']/1000   # berlin_local: 750
])

# Create solver configuration
cfg = SolverConfig(
    p=attribute_probs,
    alphas=t,                 # Constraint thresholds
    risk_tolerance=0.05,  # 5% risk tolerance
    sims=100,  # Number of simulations per decision
    reject_budget=20000, # Maximum rejections allowed
    N=1000,              # Target number to accept
    cov=covariance_matrix,
)

# Create the sampling solver
solver = OnlineQuotaSolver(cfg=cfg)

# Wrapper to convert API format to solver format
class SolverWrapper:
    def __init__(self, solver, attribute_names):
        self.solver = solver
        self.attribute_names = attribute_names
    
    def decide(self, attrs_dict):
        # Convert API format to solver format
        x = np.array([attrs_dict.get(name, False) for name in self.attribute_names], dtype=int)
        accept, _ = self.solver.decide(x)
        self.solver.update(x, accept)
        return accept

policy = SolverWrapper(solver, attribute_names)

# %%
def decide_and_next(game_id: str, person_index: int, accept: Optional[bool] = None) -> Dict[str, Any]:
    url = f"{BASE_URL}/decide-and-next"
    params = {"gameId": game_id, "personIndex": person_index}
    if accept is not None:
        params["accept"] = str(accept).lower()  # true/false in query string
    res = requests.get(url, params=params, timeout=30)
    res.raise_for_status()
    return res.json()

# %%
state = decide_and_next(game_id, person_index=0)
if state.get("status") == "failed":
    raise RuntimeError(f"Game failed: {state.get('reason')}")
print(state)
# Out:
# {'status': 'running', 'admittedCount': 0, 'rejectedCount': 0, 'nextPerson': {'personIndex': 0, 'attributes': {'techno_lover': True, 'well_connected': False, 'creative': False, 'berlin_local': False}}}

# %%
admitted = state.get("admittedCount", 0)
rejected = state.get("rejectedCount", 0)
next_person = state.get("nextPerson")

# %%
while state.get("status") == "running" and next_person:
    idx = next_person["personIndex"]
    attrs = next_person["attributes"]  # { attributeId: bool }
    accept = policy.decide(attrs)
    state = decide_and_next(game_id, person_index=idx, accept=accept)
    status = state.get("status")
    if status == "failed":
        raise RuntimeError(f"Game failed: {state.get('reason')}")

    admitted = state.get("admittedCount", admitted)
    rejected = state.get("rejectedCount", rejected)
    next_person = state.get("nextPerson")

    print(f"Person {idx}: accept={accept} | admitted={admitted} rejected={rejected}")

    # 5) done
if state.get("status") == "completed":
    print("Game completed.")
    print("Final rejected count:", state.get("rejectedCount"))
else:
    print("Game ended with state:", state)
# Out:
# Person 0: accept=False | admitted=0 rejected=1
# Person 1: accept=True | admitted=1 rejected=1
# Person 2: accept=True | admitted=2 rejected=1
# Person 3: accept=True | admitted=3 rejected=1
# Person 4: accept=True | admitted=4 rejected=1
# Person 5: accept=True | admitted=5 rejected=1
# Person 6: accept=True | admitted=6 rejected=1
# Person 7: accept=True | admitted=7 rejected=1
# Person 8: accept=True | admitted=8 rejected=1
# Person 9: accept=True | admitted=9 rejected=1
# Person 10: accept=True | admitted=10 rejected=1
# Person 11: accept=True | admitted=11 rejected=1
# Person 12: accept=True | admitted=12 rejected=1
# Person 13: accept=True | admitted=13 rejected=1
# Person 14: accept=True | admitted=14 rejected=1
# Person 15: accept=True | admitted=15 rejected=1
# Person 16: accept=True | admitted=16 rejected=1
# Person 17: accept=True | admitted=17 rejected=1
# Person 18: accept=True | admitted=18 rejected=1
# Person 19: accept=True | admitted=19 rejected=1
# Person 20: accept=True | admitted=20 rejected=1
# Person 21: accept=True | admitted=21 rejected=1
# Person 22: accept=True | admitted=22 rejected=1
# Person 23: accept=True | admitted=23 rejected=1
# Person 24: accept=True | admitted=24 rejected=1
# Person 25: accept=True | admitted=25 rejected=1
# Person 26: accept=True | admitted=26 rejected=1
# Person 27: accept=True | admitted=27 rejected=1
# Person 28: accept=True | admitted=28 rejected=1
# Person 29: accept=True | admitted=29 rejected=1
# Person 30: accept=True | admitted=30 rejected=1
# Person 31: accept=True | admitted=31 rejected=1
# Person 32: accept=True | admitted=32 rejected=1
# Person 33: accept=True | admitted=33 rejected=1
# Person 34: accept=True | admitted=34 rejected=1
# Person 35: accept=True | admitted=35 rejected=1
# Person 36: accept=True | admitted=36 rejected=1
# Person 37: accept=True | admitted=37 rejected=1
# Person 38: accept=True | admitted=38 rejected=1
# Person 39: accept=True | admitted=39 rejected=1
# Person 40: accept=True | admitted=40 rejected=1
# Person 41: accept=True | admitted=41 rejected=1
# Person 42: accept=True | admitted=42 rejected=1
# Person 43: accept=True | admitted=43 rejected=1
# Person 44: accept=True | admitted=44 rejected=1
# Person 45: accept=True | admitted=45 rejected=1
# Person 46: accept=True | admitted=46 rejected=1
# Person 47: accept=True | admitted=47 rejected=1
# Person 48: accept=True | admitted=48 rejected=1
# Person 49: accept=True | admitted=49 rejected=1
# Person 50: accept=True | admitted=50 rejected=1
# Person 51: accept=True | admitted=51 rejected=1
# Person 52: accept=True | admitted=52 rejected=1
# Person 53: accept=True | admitted=53 rejected=1
# Person 54: accept=True | admitted=54 rejected=1
# Person 55: accept=True | admitted=55 rejected=1
# Person 56: accept=True | admitted=56 rejected=1
# Person 57: accept=True | admitted=57 rejected=1
# Person 58: accept=True | admitted=58 rejected=1
# Person 59: accept=True | admitted=59 rejected=1
# Person 60: accept=True | admitted=60 rejected=1
# Person 61: accept=True | admitted=61 rejected=1
# Person 62: accept=True | admitted=62 rejected=1
# Person 63: accept=True | admitted=63 rejected=1
# Person 64: accept=True | admitted=64 rejected=1
# Person 65: accept=True | admitted=65 rejected=1
# Person 66: accept=True | admitted=66 rejected=1
# Person 67: accept=True | admitted=67 rejected=1
# Person 68: accept=True | admitted=68 rejected=1
# Person 69: accept=True | admitted=69 rejected=1
# Person 70: accept=True | admitted=70 rejected=1
# Person 71: accept=True | admitted=71 rejected=1
# Person 72: accept=True | admitted=72 rejected=1
# Person 73: accept=True | admitted=73 rejected=1
# Person 74: accept=True | admitted=74 rejected=1
# Person 75: accept=True | admitted=75 rejected=1
# Person 76: accept=True | admitted=76 rejected=1
# Person 77: accept=True | admitted=77 rejected=1
# Person 78: accept=True | admitted=78 rejected=1
# Person 79: accept=True | admitted=79 rejected=1
# Person 80: accept=True | admitted=80 rejected=1
# Person 81: accept=True | admitted=81 rejected=1
# Person 82: accept=True | admitted=82 rejected=1
# Person 83: accept=True | admitted=83 rejected=1
# Person 84: accept=True | admitted=84 rejected=1
# Person 85: accept=True | admitted=85 rejected=1
# Person 86: accept=True | admitted=86 rejected=1
# Person 87: accept=True | admitted=87 rejected=1
# Person 88: accept=True | admitted=88 rejected=1
# Person 89: accept=True | admitted=89 rejected=1
# Person 90: accept=True | admitted=90 rejected=1
# Person 91: accept=True | admitted=91 rejected=1
# Person 92: accept=True | admitted=92 rejected=1
# Person 93: accept=True | admitted=93 rejected=1
# Person 94: accept=True | admitted=94 rejected=1
# Person 95: accept=True | admitted=95 rejected=1
# Person 96: accept=True | admitted=96 rejected=1
# Person 97: accept=True | admitted=97 rejected=1
# Person 98: accept=True | admitted=98 rejected=1
# Person 99: accept=True | admitted=99 rejected=1
# Person 100: accept=True | admitted=100 rejected=1
# Person 101: accept=True | admitted=101 rejected=1
# Person 102: accept=True | admitted=102 rejected=1
# Person 103: accept=True | admitted=103 rejected=1
# Person 104: accept=True | admitted=104 rejected=1
# Person 105: accept=True | admitted=105 rejected=1
# Person 106: accept=True | admitted=106 rejected=1
# Person 107: accept=True | admitted=107 rejected=1
# Person 108: accept=True | admitted=108 rejected=1
# Person 109: accept=True | admitted=109 rejected=1
# Person 110: accept=True | admitted=110 rejected=1
# Person 111: accept=True | admitted=111 rejected=1
# Person 112: accept=True | admitted=112 rejected=1
# Person 113: accept=True | admitted=113 rejected=1
# Person 114: accept=True | admitted=114 rejected=1
# Person 115: accept=True | admitted=115 rejected=1
# Person 116: accept=True | admitted=116 rejected=1
# Person 117: accept=True | admitted=117 rejected=1
# Person 118: accept=True | admitted=118 rejected=1
# Person 119: accept=True | admitted=119 rejected=1
# Person 120: accept=True | admitted=120 rejected=1
# Person 121: accept=True | admitted=121 rejected=1
# Person 122: accept=True | admitted=122 rejected=1
# Person 123: accept=True | admitted=123 rejected=1
# Person 124: accept=True | admitted=124 rejected=1
# Person 125: accept=True | admitted=125 rejected=1
# Person 126: accept=True | admitted=126 rejected=1
# Person 127: accept=True | admitted=127 rejected=1
# Person 128: accept=True | admitted=128 rejected=1
# Person 129: accept=True | admitted=129 rejected=1
# Person 130: accept=True | admitted=130 rejected=1
# Person 131: accept=True | admitted=131 rejected=1
# Person 132: accept=True | admitted=132 rejected=1
# Person 133: accept=True | admitted=133 rejected=1
# Person 134: accept=True | admitted=134 rejected=1
# Person 135: accept=True | admitted=135 rejected=1
# Person 136: accept=True | admitted=136 rejected=1
# Person 137: accept=True | admitted=137 rejected=1
# Person 138: accept=True | admitted=138 rejected=1
# Person 139: accept=True | admitted=139 rejected=1
# Person 140: accept=True | admitted=140 rejected=1
# Person 141: accept=True | admitted=141 rejected=1
# Person 142: accept=True | admitted=142 rejected=1
# Person 143: accept=True | admitted=143 rejected=1
# Person 144: accept=True | admitted=144 rejected=1
# Person 145: accept=True | admitted=145 rejected=1
# Person 146: accept=True | admitted=146 rejected=1
# Person 147: accept=True | admitted=147 rejected=1
# Person 148: accept=True | admitted=148 rejected=1
# Person 149: accept=True | admitted=149 rejected=1
# Person 150: accept=True | admitted=150 rejected=1
# Person 151: accept=True | admitted=151 rejected=1
# Person 152: accept=True | admitted=152 rejected=1
# Person 153: accept=True | admitted=153 rejected=1
# Person 154: accept=True | admitted=154 rejected=1
# Person 155: accept=True | admitted=155 rejected=1
# Person 156: accept=True | admitted=156 rejected=1
# Person 157: accept=True | admitted=157 rejected=1
# Person 158: accept=True | admitted=158 rejected=1
# Person 159: accept=True | admitted=159 rejected=1
# Person 160: accept=True | admitted=160 rejected=1
# Person 161: accept=True | admitted=161 rejected=1
# Person 162: accept=True | admitted=162 rejected=1
# Person 163: accept=True | admitted=163 rejected=1
# Person 164: accept=True | admitted=164 rejected=1
# Person 165: accept=True | admitted=165 rejected=1
# Person 166: accept=True | admitted=166 rejected=1
# Person 167: accept=True | admitted=167 rejected=1
# Person 168: accept=True | admitted=168 rejected=1
# Person 169: accept=True | admitted=169 rejected=1
# Person 170: accept=True | admitted=170 rejected=1
# Person 171: accept=True | admitted=171 rejected=1
# Person 172: accept=True | admitted=172 rejected=1
# Person 173: accept=True | admitted=173 rejected=1
# Person 174: accept=True | admitted=174 rejected=1
# Person 175: accept=True | admitted=175 rejected=1
# Person 176: accept=True | admitted=176 rejected=1
# Person 177: accept=True | admitted=177 rejected=1
# Person 178: accept=True | admitted=178 rejected=1
# Person 179: accept=True | admitted=179 rejected=1
# Person 180: accept=True | admitted=180 rejected=1
# Person 181: accept=True | admitted=181 rejected=1
# Person 182: accept=True | admitted=182 rejected=1
# Person 183: accept=True | admitted=183 rejected=1
# Person 184: accept=True | admitted=184 rejected=1
# Person 185: accept=True | admitted=185 rejected=1
# Person 186: accept=True | admitted=186 rejected=1
# Person 187: accept=True | admitted=187 rejected=1
# Person 188: accept=True | admitted=188 rejected=1
# Person 189: accept=True | admitted=189 rejected=1
# Person 190: accept=True | admitted=190 rejected=1
# Person 191: accept=True | admitted=191 rejected=1
# Person 192: accept=True | admitted=192 rejected=1
# Person 193: accept=True | admitted=193 rejected=1
# Person 194: accept=True | admitted=194 rejected=1
# Person 195: accept=True | admitted=195 rejected=1
# Person 196: accept=True | admitted=196 rejected=1
# Person 197: accept=True | admitted=197 rejected=1
# Person 198: accept=True | admitted=198 rejected=1
# Person 199: accept=True | admitted=199 rejected=1
# Person 200: accept=True | admitted=200 rejected=1
# Person 201: accept=True | admitted=201 rejected=1
# Person 202: accept=True | admitted=202 rejected=1
# Person 203: accept=True | admitted=203 rejected=1
# Person 204: accept=True | admitted=204 rejected=1
# Person 205: accept=True | admitted=205 rejected=1
# Person 206: accept=True | admitted=206 rejected=1
# Person 207: accept=True | admitted=207 rejected=1
# Person 208: accept=True | admitted=208 rejected=1
# Person 209: accept=True | admitted=209 rejected=1
# Person 210: accept=True | admitted=210 rejected=1
# Person 211: accept=True | admitted=211 rejected=1
# Person 212: accept=True | admitted=212 rejected=1
# Person 213: accept=True | admitted=213 rejected=1
# Person 214: accept=True | admitted=214 rejected=1
# Person 215: accept=True | admitted=215 rejected=1
# Person 216: accept=True | admitted=216 rejected=1
# Person 217: accept=True | admitted=217 rejected=1
# Person 218: accept=True | admitted=218 rejected=1
# Person 219: accept=True | admitted=219 rejected=1
# Person 220: accept=True | admitted=220 rejected=1
# Person 221: accept=True | admitted=221 rejected=1
# Person 222: accept=True | admitted=222 rejected=1
# Person 223: accept=True | admitted=223 rejected=1
# Person 224: accept=True | admitted=224 rejected=1
# Person 225: accept=True | admitted=225 rejected=1
# Person 226: accept=True | admitted=226 rejected=1
# Person 227: accept=True | admitted=227 rejected=1
# Person 228: accept=True | admitted=228 rejected=1
# Person 229: accept=True | admitted=229 rejected=1
# Person 230: accept=True | admitted=230 rejected=1
# Person 231: accept=True | admitted=231 rejected=1
# Person 232: accept=True | admitted=232 rejected=1
# Person 233: accept=True | admitted=233 rejected=1
# Person 234: accept=True | admitted=234 rejected=1
# Person 235: accept=True | admitted=235 rejected=1
# Person 236: accept=True | admitted=236 rejected=1
# Person 237: accept=True | admitted=237 rejected=1
# Person 238: accept=True | admitted=238 rejected=1
# Person 239: accept=True | admitted=239 rejected=1
# Person 240: accept=True | admitted=240 rejected=1
# Person 241: accept=True | admitted=241 rejected=1
# Person 242: accept=True | admitted=242 rejected=1
# Person 243: accept=True | admitted=243 rejected=1
# Person 244: accept=True | admitted=244 rejected=1
# Person 245: accept=True | admitted=245 rejected=1
# Person 246: accept=True | admitted=246 rejected=1
# Person 247: accept=True | admitted=247 rejected=1
# Person 248: accept=True | admitted=248 rejected=1
# Person 249: accept=True | admitted=249 rejected=1
# Person 250: accept=True | admitted=250 rejected=1
# Person 251: accept=True | admitted=251 rejected=1
# Person 252: accept=True | admitted=252 rejected=1
# Person 253: accept=True | admitted=253 rejected=1
# Person 254: accept=True | admitted=254 rejected=1
# Person 255: accept=True | admitted=255 rejected=1
# Person 256: accept=True | admitted=256 rejected=1
# Person 257: accept=True | admitted=257 rejected=1
# Person 258: accept=True | admitted=258 rejected=1
# Person 259: accept=True | admitted=259 rejected=1
# Person 260: accept=True | admitted=260 rejected=1
# Person 261: accept=True | admitted=261 rejected=1
# Person 262: accept=True | admitted=262 rejected=1
# Person 263: accept=True | admitted=263 rejected=1
# Person 264: accept=True | admitted=264 rejected=1
# Person 265: accept=True | admitted=265 rejected=1
# Person 266: accept=True | admitted=266 rejected=1
# Person 267: accept=True | admitted=267 rejected=1
# Person 268: accept=True | admitted=268 rejected=1
# Person 269: accept=True | admitted=269 rejected=1
# Person 270: accept=True | admitted=270 rejected=1
# Person 271: accept=True | admitted=271 rejected=1
# Person 272: accept=True | admitted=272 rejected=1
# Person 273: accept=True | admitted=273 rejected=1
# Person 274: accept=True | admitted=274 rejected=1
# Person 275: accept=True | admitted=275 rejected=1
# Person 276: accept=True | admitted=276 rejected=1
# Person 277: accept=True | admitted=277 rejected=1
# Person 278: accept=True | admitted=278 rejected=1
# Person 279: accept=True | admitted=279 rejected=1
# Person 280: accept=True | admitted=280 rejected=1
# Person 281: accept=True | admitted=281 rejected=1
# Person 282: accept=True | admitted=282 rejected=1
# Person 283: accept=True | admitted=283 rejected=1
# Person 284: accept=True | admitted=284 rejected=1
# Person 285: accept=True | admitted=285 rejected=1
# Person 286: accept=True | admitted=286 rejected=1
# Person 287: accept=True | admitted=287 rejected=1
# Person 288: accept=True | admitted=288 rejected=1
# Person 289: accept=True | admitted=289 rejected=1
# Person 290: accept=True | admitted=290 rejected=1
# Person 291: accept=True | admitted=291 rejected=1
# Person 292: accept=True | admitted=292 rejected=1
# Person 293: accept=True | admitted=293 rejected=1
# Person 294: accept=True | admitted=294 rejected=1
# Person 295: accept=True | admitted=295 rejected=1
# Person 296: accept=True | admitted=296 rejected=1
# Person 297: accept=True | admitted=297 rejected=1
# Person 298: accept=True | admitted=298 rejected=1
# Person 299: accept=True | admitted=299 rejected=1
# Person 300: accept=True | admitted=300 rejected=1
# Person 301: accept=True | admitted=301 rejected=1
# Person 302: accept=True | admitted=302 rejected=1
# Person 303: accept=True | admitted=303 rejected=1
# Person 304: accept=True | admitted=304 rejected=1
# Person 305: accept=True | admitted=305 rejected=1
# Person 306: accept=True | admitted=306 rejected=1
# Person 307: accept=True | admitted=307 rejected=1
# Person 308: accept=True | admitted=308 rejected=1
# Person 309: accept=True | admitted=309 rejected=1
# Person 310: accept=True | admitted=310 rejected=1
# Person 311: accept=True | admitted=311 rejected=1
# Person 312: accept=True | admitted=312 rejected=1
# Person 313: accept=True | admitted=313 rejected=1
# Person 314: accept=True | admitted=314 rejected=1
# Person 315: accept=True | admitted=315 rejected=1
# Person 316: accept=True | admitted=316 rejected=1
# Person 317: accept=True | admitted=317 rejected=1
# Person 318: accept=True | admitted=318 rejected=1
# Person 319: accept=True | admitted=319 rejected=1
# Person 320: accept=True | admitted=320 rejected=1
# Person 321: accept=True | admitted=321 rejected=1
# Person 322: accept=True | admitted=322 rejected=1
# Person 323: accept=True | admitted=323 rejected=1
# Person 324: accept=True | admitted=324 rejected=1
# Person 325: accept=True | admitted=325 rejected=1
# Person 326: accept=True | admitted=326 rejected=1
# Person 327: accept=True | admitted=327 rejected=1
# Person 328: accept=True | admitted=328 rejected=1
# Person 329: accept=True | admitted=329 rejected=1
# Person 330: accept=True | admitted=330 rejected=1
# Person 331: accept=True | admitted=331 rejected=1
# Person 332: accept=True | admitted=332 rejected=1
# Person 333: accept=True | admitted=333 rejected=1
# Person 334: accept=True | admitted=334 rejected=1
# Person 335: accept=True | admitted=335 rejected=1
# Person 336: accept=True | admitted=336 rejected=1
# Person 337: accept=True | admitted=337 rejected=1
# Person 338: accept=True | admitted=338 rejected=1
# Person 339: accept=True | admitted=339 rejected=1
# Person 340: accept=True | admitted=340 rejected=1
# Person 341: accept=True | admitted=341 rejected=1
# Person 342: accept=True | admitted=342 rejected=1
# Person 343: accept=True | admitted=343 rejected=1
# Person 344: accept=True | admitted=344 rejected=1
# Person 345: accept=True | admitted=345 rejected=1
# Person 346: accept=True | admitted=346 rejected=1
# Person 347: accept=True | admitted=347 rejected=1
# Person 348: accept=True | admitted=348 rejected=1
# Person 349: accept=True | admitted=349 rejected=1
# Person 350: accept=True | admitted=350 rejected=1
# Person 351: accept=True | admitted=351 rejected=1
# Person 352: accept=True | admitted=352 rejected=1
# Person 353: accept=True | admitted=353 rejected=1
# Person 354: accept=True | admitted=354 rejected=1
# Person 355: accept=True | admitted=355 rejected=1
# Person 356: accept=True | admitted=356 rejected=1
# Person 357: accept=True | admitted=357 rejected=1
# Person 358: accept=True | admitted=358 rejected=1
# Person 359: accept=True | admitted=359 rejected=1
# Person 360: accept=True | admitted=360 rejected=1
# Person 361: accept=True | admitted=361 rejected=1
# Person 362: accept=True | admitted=362 rejected=1
# Person 363: accept=True | admitted=363 rejected=1
# Person 364: accept=True | admitted=364 rejected=1
# Person 365: accept=True | admitted=365 rejected=1
# Person 366: accept=True | admitted=366 rejected=1
# Person 367: accept=True | admitted=367 rejected=1
# Person 368: accept=True | admitted=368 rejected=1
# Person 369: accept=True | admitted=369 rejected=1
# Person 370: accept=True | admitted=370 rejected=1
# Person 371: accept=True | admitted=371 rejected=1
# Person 372: accept=True | admitted=372 rejected=1
# Person 373: accept=True | admitted=373 rejected=1
# Person 374: accept=True | admitted=374 rejected=1
# Person 375: accept=True | admitted=375 rejected=1
# Person 376: accept=True | admitted=376 rejected=1
# Person 377: accept=True | admitted=377 rejected=1
# Person 378: accept=True | admitted=378 rejected=1
# Person 379: accept=True | admitted=379 rejected=1
# Person 380: accept=True | admitted=380 rejected=1
# Person 381: accept=True | admitted=381 rejected=1
# Person 382: accept=True | admitted=382 rejected=1
# Person 383: accept=True | admitted=383 rejected=1
# Person 384: accept=True | admitted=384 rejected=1
# Person 385: accept=True | admitted=385 rejected=1
# Person 386: accept=True | admitted=386 rejected=1
# Person 387: accept=True | admitted=387 rejected=1
# Person 388: accept=True | admitted=388 rejected=1
# Person 389: accept=True | admitted=389 rejected=1
# Person 390: accept=True | admitted=390 rejected=1
# Person 391: accept=True | admitted=391 rejected=1
# Person 392: accept=True | admitted=392 rejected=1
# Person 393: accept=True | admitted=393 rejected=1
# Person 394: accept=True | admitted=394 rejected=1
# Person 395: accept=True | admitted=395 rejected=1
# Person 396: accept=True | admitted=396 rejected=1
# Person 397: accept=True | admitted=397 rejected=1
# Person 398: accept=True | admitted=398 rejected=1
# Person 399: accept=True | admitted=399 rejected=1
# Person 400: accept=True | admitted=400 rejected=1
# Person 401: accept=True | admitted=401 rejected=1
# Person 402: accept=True | admitted=402 rejected=1
# Person 403: accept=True | admitted=403 rejected=1
# Person 404: accept=True | admitted=404 rejected=1
# Person 405: accept=True | admitted=405 rejected=1
# Person 406: accept=True | admitted=406 rejected=1
# Person 407: accept=True | admitted=407 rejected=1
# Person 408: accept=True | admitted=408 rejected=1
# Person 409: accept=True | admitted=409 rejected=1
# Person 410: accept=True | admitted=410 rejected=1
# Person 411: accept=True | admitted=411 rejected=1
# Person 412: accept=True | admitted=412 rejected=1
# Person 413: accept=True | admitted=413 rejected=1
# Person 414: accept=True | admitted=414 rejected=1
# Person 415: accept=True | admitted=415 rejected=1
# Person 416: accept=True | admitted=416 rejected=1
# Person 417: accept=True | admitted=417 rejected=1
# Person 418: accept=True | admitted=418 rejected=1
# Person 419: accept=True | admitted=419 rejected=1
# Person 420: accept=True | admitted=420 rejected=1
# Person 421: accept=True | admitted=421 rejected=1
# Person 422: accept=True | admitted=422 rejected=1
# Person 423: accept=True | admitted=423 rejected=1
# Person 424: accept=True | admitted=424 rejected=1
# Person 425: accept=True | admitted=425 rejected=1
# Person 426: accept=True | admitted=426 rejected=1
# Person 427: accept=True | admitted=427 rejected=1
# Person 428: accept=True | admitted=428 rejected=1
# Person 429: accept=True | admitted=429 rejected=1
# Person 430: accept=True | admitted=430 rejected=1
# Person 431: accept=True | admitted=431 rejected=1
# Person 432: accept=True | admitted=432 rejected=1
# Person 433: accept=True | admitted=433 rejected=1
# Person 434: accept=True | admitted=434 rejected=1
# Person 435: accept=True | admitted=435 rejected=1
# Person 436: accept=True | admitted=436 rejected=1
# Person 437: accept=True | admitted=437 rejected=1
# Person 438: accept=True | admitted=438 rejected=1
# Person 439: accept=True | admitted=439 rejected=1
# Person 440: accept=True | admitted=440 rejected=1
# Person 441: accept=True | admitted=441 rejected=1
# Person 442: accept=True | admitted=442 rejected=1
# Person 443: accept=True | admitted=443 rejected=1
# Person 444: accept=True | admitted=444 rejected=1
# Person 445: accept=True | admitted=445 rejected=1
# Person 446: accept=True | admitted=446 rejected=1
# Person 447: accept=True | admitted=447 rejected=1
# Person 448: accept=True | admitted=448 rejected=1
# Person 449: accept=True | admitted=449 rejected=1
# Person 450: accept=True | admitted=450 rejected=1
# Person 451: accept=True | admitted=451 rejected=1
# Person 452: accept=True | admitted=452 rejected=1
# Person 453: accept=True | admitted=453 rejected=1
# Person 454: accept=True | admitted=454 rejected=1
# Person 455: accept=True | admitted=455 rejected=1
# Person 456: accept=True | admitted=456 rejected=1
# Person 457: accept=True | admitted=457 rejected=1
# Person 458: accept=True | admitted=458 rejected=1
# Person 459: accept=True | admitted=459 rejected=1
# Person 460: accept=True | admitted=460 rejected=1
# Person 461: accept=True | admitted=461 rejected=1
# Person 462: accept=True | admitted=462 rejected=1
# Person 463: accept=True | admitted=463 rejected=1
# Person 464: accept=True | admitted=464 rejected=1
# Person 465: accept=True | admitted=465 rejected=1
# Person 466: accept=True | admitted=466 rejected=1
# Person 467: accept=True | admitted=467 rejected=1
# Person 468: accept=True | admitted=468 rejected=1
# Person 469: accept=True | admitted=469 rejected=1
# Person 470: accept=True | admitted=470 rejected=1
# Person 471: accept=True | admitted=471 rejected=1
# Person 472: accept=True | admitted=472 rejected=1
# Person 473: accept=True | admitted=473 rejected=1
# Person 474: accept=True | admitted=474 rejected=1
# Person 475: accept=True | admitted=475 rejected=1
# Person 476: accept=True | admitted=476 rejected=1
# Person 477: accept=True | admitted=477 rejected=1
# Person 478: accept=True | admitted=478 rejected=1
# Person 479: accept=True | admitted=479 rejected=1
# Person 480: accept=True | admitted=480 rejected=1
# Person 481: accept=True | admitted=481 rejected=1
# Person 482: accept=True | admitted=482 rejected=1
# Person 483: accept=True | admitted=483 rejected=1
# Person 484: accept=True | admitted=484 rejected=1
# Person 485: accept=True | admitted=485 rejected=1
# Person 486: accept=True | admitted=486 rejected=1
# Person 487: accept=True | admitted=487 rejected=1
# Person 488: accept=True | admitted=488 rejected=1
# Person 489: accept=True | admitted=489 rejected=1
# Person 490: accept=True | admitted=490 rejected=1
# Person 491: accept=True | admitted=491 rejected=1
# Person 492: accept=True | admitted=492 rejected=1
# Person 493: accept=True | admitted=493 rejected=1
# Person 494: accept=True | admitted=494 rejected=1
# Person 495: accept=True | admitted=495 rejected=1
# Person 496: accept=True | admitted=496 rejected=1
# Person 497: accept=True | admitted=497 rejected=1
# Person 498: accept=True | admitted=498 rejected=1
# Person 499: accept=True | admitted=499 rejected=1
# Person 500: accept=True | admitted=500 rejected=1
# Person 501: accept=True | admitted=501 rejected=1
# Person 502: accept=True | admitted=502 rejected=1
# Person 503: accept=True | admitted=503 rejected=1
# Person 504: accept=True | admitted=504 rejected=1
# Person 505: accept=True | admitted=505 rejected=1
# Person 506: accept=True | admitted=506 rejected=1
# Person 507: accept=True | admitted=507 rejected=1
# Person 508: accept=True | admitted=508 rejected=1
# Person 509: accept=True | admitted=509 rejected=1
# Person 510: accept=True | admitted=510 rejected=1
# Person 511: accept=True | admitted=511 rejected=1
# Person 512: accept=True | admitted=512 rejected=1
# Person 513: accept=True | admitted=513 rejected=1
# Person 514: accept=True | admitted=514 rejected=1
# Person 515: accept=True | admitted=515 rejected=1
# Person 516: accept=True | admitted=516 rejected=1
# Person 517: accept=True | admitted=517 rejected=1
# Person 518: accept=True | admitted=518 rejected=1
# Person 519: accept=True | admitted=519 rejected=1
# Person 520: accept=True | admitted=520 rejected=1
# Person 521: accept=True | admitted=521 rejected=1
# Person 522: accept=True | admitted=522 rejected=1
# Person 523: accept=True | admitted=523 rejected=1
# Person 524: accept=True | admitted=524 rejected=1
# Person 525: accept=True | admitted=525 rejected=1
# Person 526: accept=True | admitted=526 rejected=1
# Person 527: accept=True | admitted=527 rejected=1
# Person 528: accept=True | admitted=528 rejected=1
# Person 529: accept=True | admitted=529 rejected=1
# Person 530: accept=True | admitted=530 rejected=1
# Person 531: accept=True | admitted=531 rejected=1
# Person 532: accept=True | admitted=532 rejected=1
# Person 533: accept=True | admitted=533 rejected=1
# Person 534: accept=True | admitted=534 rejected=1
# Person 535: accept=True | admitted=535 rejected=1
# Person 536: accept=True | admitted=536 rejected=1
# Person 537: accept=True | admitted=537 rejected=1
# Person 538: accept=True | admitted=538 rejected=1
# Person 539: accept=True | admitted=539 rejected=1
# Person 540: accept=True | admitted=540 rejected=1
# Person 541: accept=True | admitted=541 rejected=1
# Person 542: accept=True | admitted=542 rejected=1
# Person 543: accept=True | admitted=543 rejected=1
# Person 544: accept=True | admitted=544 rejected=1
# Person 545: accept=True | admitted=545 rejected=1
# Person 546: accept=True | admitted=546 rejected=1
# Person 547: accept=True | admitted=547 rejected=1
# Person 548: accept=True | admitted=548 rejected=1
# Person 549: accept=True | admitted=549 rejected=1
# Person 550: accept=True | admitted=550 rejected=1
# Person 551: accept=True | admitted=551 rejected=1
# Person 552: accept=True | admitted=552 rejected=1
# Person 553: accept=True | admitted=553 rejected=1
# Person 554: accept=True | admitted=554 rejected=1
# Person 555: accept=True | admitted=555 rejected=1
# Person 556: accept=True | admitted=556 rejected=1
# Person 557: accept=True | admitted=557 rejected=1
# Person 558: accept=True | admitted=558 rejected=1
# Person 559: accept=True | admitted=559 rejected=1
# Person 560: accept=True | admitted=560 rejected=1
# Person 561: accept=True | admitted=561 rejected=1
# Person 562: accept=True | admitted=562 rejected=1
# Person 563: accept=True | admitted=563 rejected=1
# Person 564: accept=True | admitted=564 rejected=1
# Person 565: accept=True | admitted=565 rejected=1
# Person 566: accept=True | admitted=566 rejected=1
# Person 567: accept=True | admitted=567 rejected=1
# Person 568: accept=True | admitted=568 rejected=1
# Person 569: accept=True | admitted=569 rejected=1
# Person 570: accept=True | admitted=570 rejected=1
# Person 571: accept=True | admitted=571 rejected=1
# Person 572: accept=True | admitted=572 rejected=1
# Person 573: accept=True | admitted=573 rejected=1
# Person 574: accept=True | admitted=574 rejected=1
# Person 575: accept=True | admitted=575 rejected=1
# Person 576: accept=True | admitted=576 rejected=1
# Person 577: accept=True | admitted=577 rejected=1
# Person 578: accept=True | admitted=578 rejected=1
# Person 579: accept=True | admitted=579 rejected=1
# Person 580: accept=True | admitted=580 rejected=1
# Person 581: accept=True | admitted=581 rejected=1
# Person 582: accept=True | admitted=582 rejected=1
# Person 583: accept=True | admitted=583 rejected=1
# Person 584: accept=True | admitted=584 rejected=1
# Person 585: accept=True | admitted=585 rejected=1
# Person 586: accept=True | admitted=586 rejected=1
# Person 587: accept=True | admitted=587 rejected=1
# Person 588: accept=True | admitted=588 rejected=1
# Person 589: accept=True | admitted=589 rejected=1
# Person 590: accept=True | admitted=590 rejected=1
# Person 591: accept=True | admitted=591 rejected=1
# Person 592: accept=True | admitted=592 rejected=1
# Person 593: accept=True | admitted=593 rejected=1
# Person 594: accept=True | admitted=594 rejected=1
# Person 595: accept=True | admitted=595 rejected=1
# Person 596: accept=True | admitted=596 rejected=1
# Person 597: accept=True | admitted=597 rejected=1
# Person 598: accept=True | admitted=598 rejected=1
# Person 599: accept=True | admitted=599 rejected=1
# Person 600: accept=True | admitted=600 rejected=1
# Person 601: accept=True | admitted=601 rejected=1
# Person 602: accept=True | admitted=602 rejected=1
# Person 603: accept=True | admitted=603 rejected=1
# Person 604: accept=True | admitted=604 rejected=1
# Person 605: accept=True | admitted=605 rejected=1
# Person 606: accept=True | admitted=606 rejected=1
# Person 607: accept=True | admitted=607 rejected=1
# Person 608: accept=True | admitted=608 rejected=1
# Person 609: accept=True | admitted=609 rejected=1
# Person 610: accept=True | admitted=610 rejected=1
# Person 611: accept=True | admitted=611 rejected=1
# Person 612: accept=True | admitted=612 rejected=1
# Person 613: accept=True | admitted=613 rejected=1
# Person 614: accept=True | admitted=614 rejected=1
# Person 615: accept=True | admitted=615 rejected=1
# Person 616: accept=True | admitted=616 rejected=1
# Person 617: accept=True | admitted=617 rejected=1
# Person 618: accept=True | admitted=618 rejected=1
# Person 619: accept=True | admitted=619 rejected=1
# Person 620: accept=True | admitted=620 rejected=1
# Person 621: accept=True | admitted=621 rejected=1
# Person 622: accept=True | admitted=622 rejected=1
# Person 623: accept=True | admitted=623 rejected=1
# Person 624: accept=True | admitted=624 rejected=1
# Person 625: accept=True | admitted=625 rejected=1
# Person 626: accept=True | admitted=626 rejected=1
# Person 627: accept=True | admitted=627 rejected=1
# Person 628: accept=True | admitted=628 rejected=1
# Person 629: accept=True | admitted=629 rejected=1
# Person 630: accept=True | admitted=630 rejected=1
# Person 631: accept=True | admitted=631 rejected=1
# Person 632: accept=True | admitted=632 rejected=1
# Person 633: accept=True | admitted=633 rejected=1
# Person 634: accept=True | admitted=634 rejected=1
# Person 635: accept=True | admitted=635 rejected=1
# Person 636: accept=True | admitted=636 rejected=1
# Person 637: accept=True | admitted=637 rejected=1
# Person 638: accept=True | admitted=638 rejected=1
# Person 639: accept=True | admitted=639 rejected=1
# Person 640: accept=True | admitted=640 rejected=1
# Person 641: accept=True | admitted=641 rejected=1
# Person 642: accept=True | admitted=642 rejected=1
# Person 643: accept=True | admitted=643 rejected=1
# Person 644: accept=True | admitted=644 rejected=1
# Person 645: accept=True | admitted=645 rejected=1
# Person 646: accept=True | admitted=646 rejected=1
# Person 647: accept=True | admitted=647 rejected=1
# Person 648: accept=True | admitted=648 rejected=1
# Person 649: accept=True | admitted=649 rejected=1
# Person 650: accept=True | admitted=650 rejected=1
# Person 651: accept=True | admitted=651 rejected=1
# Person 652: accept=True | admitted=652 rejected=1
# Person 653: accept=True | admitted=653 rejected=1
# Person 654: accept=True | admitted=654 rejected=1
# Person 655: accept=True | admitted=655 rejected=1
# Person 656: accept=True | admitted=656 rejected=1
# Person 657: accept=True | admitted=657 rejected=1
# Person 658: accept=True | admitted=658 rejected=1
# Person 659: accept=True | admitted=659 rejected=1
# Person 660: accept=True | admitted=660 rejected=1
# Person 661: accept=True | admitted=661 rejected=1
# Person 662: accept=True | admitted=662 rejected=1
# Person 663: accept=True | admitted=663 rejected=1
# Person 664: accept=True | admitted=664 rejected=1
# Person 665: accept=True | admitted=665 rejected=1
# Person 666: accept=True | admitted=666 rejected=1
# Person 667: accept=True | admitted=667 rejected=1
# Person 668: accept=True | admitted=668 rejected=1
# Person 669: accept=True | admitted=669 rejected=1
# Person 670: accept=True | admitted=670 rejected=1
# Person 671: accept=True | admitted=671 rejected=1
# Person 672: accept=True | admitted=672 rejected=1
# Person 673: accept=True | admitted=673 rejected=1
# Person 674: accept=True | admitted=674 rejected=1
# Person 675: accept=True | admitted=675 rejected=1
# Person 676: accept=True | admitted=676 rejected=1
# Person 677: accept=True | admitted=677 rejected=1
# Person 678: accept=True | admitted=678 rejected=1
# Person 679: accept=True | admitted=679 rejected=1
# Person 680: accept=True | admitted=680 rejected=1
# Person 681: accept=True | admitted=681 rejected=1
# Person 682: accept=True | admitted=682 rejected=1
# Person 683: accept=True | admitted=683 rejected=1
# Person 684: accept=True | admitted=684 rejected=1
# Person 685: accept=True | admitted=685 rejected=1
# Person 686: accept=True | admitted=686 rejected=1
# Person 687: accept=True | admitted=687 rejected=1
# Person 688: accept=True | admitted=688 rejected=1
# Person 689: accept=True | admitted=689 rejected=1
# Person 690: accept=True | admitted=690 rejected=1
# Person 691: accept=True | admitted=691 rejected=1
# Person 692: accept=True | admitted=692 rejected=1
# Person 693: accept=True | admitted=693 rejected=1
# Person 694: accept=True | admitted=694 rejected=1
# Person 695: accept=True | admitted=695 rejected=1
# Person 696: accept=True | admitted=696 rejected=1
# Person 697: accept=True | admitted=697 rejected=1
# Person 698: accept=True | admitted=698 rejected=1
# Person 699: accept=True | admitted=699 rejected=1
# Person 700: accept=True | admitted=700 rejected=1
# Person 701: accept=True | admitted=701 rejected=1
# Person 702: accept=True | admitted=702 rejected=1
# Person 703: accept=True | admitted=703 rejected=1
# Person 704: accept=True | admitted=704 rejected=1
# Person 705: accept=True | admitted=705 rejected=1
# Person 706: accept=True | admitted=706 rejected=1
# Person 707: accept=True | admitted=707 rejected=1
# Person 708: accept=True | admitted=708 rejected=1
# Person 709: accept=True | admitted=709 rejected=1
# Person 710: accept=True | admitted=710 rejected=1
# Person 711: accept=True | admitted=711 rejected=1
# Person 712: accept=True | admitted=712 rejected=1
# Person 713: accept=True | admitted=713 rejected=1
# Person 714: accept=True | admitted=714 rejected=1
# Person 715: accept=True | admitted=715 rejected=1
# Person 716: accept=True | admitted=716 rejected=1
# Person 717: accept=True | admitted=717 rejected=1
# Person 718: accept=True | admitted=718 rejected=1
# Person 719: accept=True | admitted=719 rejected=1
# Person 720: accept=True | admitted=720 rejected=1
# Person 721: accept=True | admitted=721 rejected=1
# Person 722: accept=True | admitted=722 rejected=1
# Person 723: accept=True | admitted=723 rejected=1
# Person 724: accept=True | admitted=724 rejected=1
# Person 725: accept=True | admitted=725 rejected=1
# Person 726: accept=True | admitted=726 rejected=1
# Person 727: accept=True | admitted=727 rejected=1
# Person 728: accept=True | admitted=728 rejected=1
# Person 729: accept=True | admitted=729 rejected=1
# Person 730: accept=True | admitted=730 rejected=1
# Person 731: accept=True | admitted=731 rejected=1
# Person 732: accept=True | admitted=732 rejected=1
# Person 733: accept=True | admitted=733 rejected=1
# Person 734: accept=True | admitted=734 rejected=1
# Person 735: accept=True | admitted=735 rejected=1
# Person 736: accept=True | admitted=736 rejected=1
# Person 737: accept=True | admitted=737 rejected=1
# Person 738: accept=True | admitted=738 rejected=1
# Person 739: accept=True | admitted=739 rejected=1
# Person 740: accept=True | admitted=740 rejected=1
# Person 741: accept=True | admitted=741 rejected=1
# Person 742: accept=True | admitted=742 rejected=1
# Person 743: accept=True | admitted=743 rejected=1
# Person 744: accept=True | admitted=744 rejected=1
# Person 745: accept=True | admitted=745 rejected=1
# Person 746: accept=True | admitted=746 rejected=1
# Person 747: accept=True | admitted=747 rejected=1
# Person 748: accept=True | admitted=748 rejected=1
# Person 749: accept=True | admitted=749 rejected=1
# Person 750: accept=True | admitted=750 rejected=1
# Person 751: accept=True | admitted=751 rejected=1
# Person 752: accept=True | admitted=752 rejected=1
# Person 753: accept=True | admitted=753 rejected=1
# Person 754: accept=True | admitted=754 rejected=1
# Person 755: accept=True | admitted=755 rejected=1
# Person 756: accept=True | admitted=756 rejected=1
# Person 757: accept=True | admitted=757 rejected=1
# Person 758: accept=True | admitted=758 rejected=1
# Person 759: accept=True | admitted=759 rejected=1
# Person 760: accept=True | admitted=760 rejected=1
# Person 761: accept=True | admitted=761 rejected=1
# Person 762: accept=True | admitted=762 rejected=1
# Person 763: accept=True | admitted=763 rejected=1
# Person 764: accept=True | admitted=764 rejected=1
# Person 765: accept=True | admitted=765 rejected=1
# Person 766: accept=True | admitted=766 rejected=1
# Person 767: accept=True | admitted=767 rejected=1
# Person 768: accept=True | admitted=768 rejected=1
# Person 769: accept=True | admitted=769 rejected=1
# Person 770: accept=True | admitted=770 rejected=1
# Person 771: accept=True | admitted=771 rejected=1
# Person 772: accept=True | admitted=772 rejected=1
# Person 773: accept=True | admitted=773 rejected=1
# Person 774: accept=True | admitted=774 rejected=1
# Person 775: accept=True | admitted=775 rejected=1
# Person 776: accept=True | admitted=776 rejected=1
# Person 777: accept=True | admitted=777 rejected=1
# Person 778: accept=True | admitted=778 rejected=1
# Person 779: accept=True | admitted=779 rejected=1
# Person 780: accept=True | admitted=780 rejected=1
# Person 781: accept=True | admitted=781 rejected=1
# Person 782: accept=True | admitted=782 rejected=1
# Person 783: accept=True | admitted=783 rejected=1
# Person 784: accept=True | admitted=784 rejected=1
# Person 785: accept=True | admitted=785 rejected=1
# Person 786: accept=True | admitted=786 rejected=1
# Person 787: accept=True | admitted=787 rejected=1
# Person 788: accept=True | admitted=788 rejected=1
# Person 789: accept=True | admitted=789 rejected=1
# Person 790: accept=True | admitted=790 rejected=1
# Person 791: accept=True | admitted=791 rejected=1
# Person 792: accept=True | admitted=792 rejected=1
# Person 793: accept=True | admitted=793 rejected=1
# Person 794: accept=True | admitted=794 rejected=1
# Person 795: accept=True | admitted=795 rejected=1
# Person 796: accept=True | admitted=796 rejected=1
# Person 797: accept=True | admitted=797 rejected=1
# Person 798: accept=True | admitted=798 rejected=1
# Person 799: accept=True | admitted=799 rejected=1
# Person 800: accept=True | admitted=800 rejected=1
# Person 801: accept=True | admitted=801 rejected=1
# Person 802: accept=True | admitted=802 rejected=1
# Person 803: accept=True | admitted=803 rejected=1
# Person 804: accept=True | admitted=804 rejected=1
# Person 805: accept=True | admitted=805 rejected=1
# Person 806: accept=True | admitted=806 rejected=1
# Person 807: accept=True | admitted=807 rejected=1
# Person 808: accept=True | admitted=808 rejected=1
# Person 809: accept=True | admitted=809 rejected=1
# Person 810: accept=True | admitted=810 rejected=1
# Person 811: accept=True | admitted=811 rejected=1
# Person 812: accept=True | admitted=812 rejected=1
# Person 813: accept=True | admitted=813 rejected=1
# Person 814: accept=True | admitted=814 rejected=1
# Person 815: accept=True | admitted=815 rejected=1
# Person 816: accept=True | admitted=816 rejected=1
# Person 817: accept=True | admitted=817 rejected=1
# Person 818: accept=True | admitted=818 rejected=1
# Person 819: accept=True | admitted=819 rejected=1
# Person 820: accept=True | admitted=820 rejected=1
# Person 821: accept=True | admitted=821 rejected=1
# Person 822: accept=True | admitted=822 rejected=1
# Person 823: accept=True | admitted=823 rejected=1
# Person 824: accept=True | admitted=824 rejected=1
# Person 825: accept=True | admitted=825 rejected=1
# Person 826: accept=True | admitted=826 rejected=1
# Person 827: accept=True | admitted=827 rejected=1
# Person 828: accept=True | admitted=828 rejected=1
# Person 829: accept=True | admitted=829 rejected=1
# Person 830: accept=True | admitted=830 rejected=1
# Person 831: accept=True | admitted=831 rejected=1
# Person 832: accept=True | admitted=832 rejected=1
# Person 833: accept=True | admitted=833 rejected=1
# Person 834: accept=True | admitted=834 rejected=1
# Person 835: accept=True | admitted=835 rejected=1
# Person 836: accept=True | admitted=836 rejected=1
# Person 837: accept=True | admitted=837 rejected=1
# Person 838: accept=True | admitted=838 rejected=1
# Person 839: accept=True | admitted=839 rejected=1
# Person 840: accept=True | admitted=840 rejected=1
# Person 841: accept=True | admitted=841 rejected=1
# Person 842: accept=True | admitted=842 rejected=1
# Person 843: accept=True | admitted=843 rejected=1
# Person 844: accept=True | admitted=844 rejected=1
# Person 845: accept=True | admitted=845 rejected=1
# Person 846: accept=True | admitted=846 rejected=1
# Person 847: accept=True | admitted=847 rejected=1
# Person 848: accept=True | admitted=848 rejected=1
# Person 849: accept=True | admitted=849 rejected=1
# Person 850: accept=True | admitted=850 rejected=1
# Person 851: accept=True | admitted=851 rejected=1
# Person 852: accept=True | admitted=852 rejected=1
# Person 853: accept=True | admitted=853 rejected=1
# Person 854: accept=True | admitted=854 rejected=1
# Person 855: accept=True | admitted=855 rejected=1
# Person 856: accept=True | admitted=856 rejected=1
# Person 857: accept=True | admitted=857 rejected=1
# Person 858: accept=True | admitted=858 rejected=1
# Person 859: accept=True | admitted=859 rejected=1
# Person 860: accept=True | admitted=860 rejected=1
# Person 861: accept=True | admitted=861 rejected=1
# Person 862: accept=True | admitted=862 rejected=1
# Person 863: accept=True | admitted=863 rejected=1
# Person 864: accept=True | admitted=864 rejected=1
# Person 865: accept=True | admitted=865 rejected=1
# Person 866: accept=True | admitted=866 rejected=1
# Person 867: accept=True | admitted=867 rejected=1
# Person 868: accept=True | admitted=868 rejected=1
# Person 869: accept=True | admitted=869 rejected=1
# Person 870: accept=True | admitted=870 rejected=1
# Person 871: accept=True | admitted=871 rejected=1
# Person 872: accept=True | admitted=872 rejected=1
# Person 873: accept=True | admitted=873 rejected=1
# Person 874: accept=True | admitted=874 rejected=1
# Person 875: accept=True | admitted=875 rejected=1
# Person 876: accept=True | admitted=876 rejected=1
# Person 877: accept=True | admitted=877 rejected=1
# Person 878: accept=True | admitted=878 rejected=1
# Person 879: accept=True | admitted=879 rejected=1
# Person 880: accept=True | admitted=880 rejected=1
# Person 881: accept=True | admitted=881 rejected=1
# Person 882: accept=True | admitted=882 rejected=1
# Person 883: accept=True | admitted=883 rejected=1
# Person 884: accept=True | admitted=884 rejected=1
# Person 885: accept=True | admitted=885 rejected=1
# Person 886: accept=True | admitted=886 rejected=1
# Person 887: accept=True | admitted=887 rejected=1
# Person 888: accept=True | admitted=888 rejected=1
# Person 889: accept=True | admitted=889 rejected=1
# Person 890: accept=True | admitted=890 rejected=1
# Person 891: accept=True | admitted=891 rejected=1
# Person 892: accept=True | admitted=892 rejected=1
# Person 893: accept=True | admitted=893 rejected=1
# Person 894: accept=True | admitted=894 rejected=1
# Person 895: accept=True | admitted=895 rejected=1
# Person 896: accept=True | admitted=896 rejected=1
# Person 897: accept=True | admitted=897 rejected=1
# Person 898: accept=True | admitted=898 rejected=1
# Person 899: accept=True | admitted=899 rejected=1
# Person 900: accept=True | admitted=900 rejected=1
# Person 901: accept=True | admitted=901 rejected=1
# Person 902: accept=True | admitted=902 rejected=1
# Person 903: accept=True | admitted=903 rejected=1
# Person 904: accept=True | admitted=904 rejected=1
# Person 905: accept=True | admitted=905 rejected=1
# Person 906: accept=True | admitted=906 rejected=1
# Person 907: accept=True | admitted=907 rejected=1
# Person 908: accept=True | admitted=908 rejected=1
# Person 909: accept=True | admitted=909 rejected=1
# Person 910: accept=True | admitted=910 rejected=1
# Person 911: accept=True | admitted=911 rejected=1
# Person 912: accept=True | admitted=912 rejected=1
# Person 913: accept=True | admitted=913 rejected=1
# Person 914: accept=True | admitted=914 rejected=1
# Person 915: accept=True | admitted=915 rejected=1
# Person 916: accept=True | admitted=916 rejected=1
# Person 917: accept=True | admitted=917 rejected=1
# Person 918: accept=True | admitted=918 rejected=1
# Person 919: accept=True | admitted=919 rejected=1
# Person 920: accept=True | admitted=920 rejected=1
# Person 921: accept=True | admitted=921 rejected=1
# Person 922: accept=True | admitted=922 rejected=1
# Person 923: accept=True | admitted=923 rejected=1
# Person 924: accept=True | admitted=924 rejected=1
# Person 925: accept=True | admitted=925 rejected=1
# Person 926: accept=True | admitted=926 rejected=1
# Person 927: accept=True | admitted=927 rejected=1
# Person 928: accept=True | admitted=928 rejected=1
# Person 929: accept=True | admitted=929 rejected=1
# Person 930: accept=True | admitted=930 rejected=1
# Person 931: accept=True | admitted=931 rejected=1
# Person 932: accept=True | admitted=932 rejected=1
# Person 933: accept=True | admitted=933 rejected=1
# Person 934: accept=True | admitted=934 rejected=1
# Person 935: accept=True | admitted=935 rejected=1
# Person 936: accept=True | admitted=936 rejected=1
# Person 937: accept=True | admitted=937 rejected=1
# Person 938: accept=True | admitted=938 rejected=1
# Person 939: accept=True | admitted=939 rejected=1
# Person 940: accept=True | admitted=940 rejected=1
# Person 941: accept=True | admitted=941 rejected=1
# Person 942: accept=True | admitted=942 rejected=1
# Person 943: accept=True | admitted=943 rejected=1
# Person 944: accept=True | admitted=944 rejected=1
# Person 945: accept=True | admitted=945 rejected=1
# Person 946: accept=True | admitted=946 rejected=1
# Person 947: accept=True | admitted=947 rejected=1
# Person 948: accept=True | admitted=948 rejected=1
# Person 949: accept=True | admitted=949 rejected=1
# Person 950: accept=True | admitted=950 rejected=1
# Person 951: accept=True | admitted=951 rejected=1
# Person 952: accept=True | admitted=952 rejected=1
# Person 953: accept=True | admitted=953 rejected=1
# Person 954: accept=True | admitted=954 rejected=1
# Person 955: accept=True | admitted=955 rejected=1
# Person 956: accept=True | admitted=956 rejected=1
# Person 957: accept=True | admitted=957 rejected=1
# Person 958: accept=True | admitted=958 rejected=1
# Person 959: accept=True | admitted=959 rejected=1
# Person 960: accept=True | admitted=960 rejected=1
# Person 961: accept=True | admitted=961 rejected=1
# Person 962: accept=True | admitted=962 rejected=1
# Person 963: accept=True | admitted=963 rejected=1
# Person 964: accept=True | admitted=964 rejected=1
# Person 965: accept=True | admitted=965 rejected=1
# Person 966: accept=True | admitted=966 rejected=1
# Person 967: accept=True | admitted=967 rejected=1
# Person 968: accept=True | admitted=968 rejected=1
# Person 969: accept=True | admitted=969 rejected=1
# Person 970: accept=True | admitted=970 rejected=1
# Person 971: accept=True | admitted=971 rejected=1
# Person 972: accept=True | admitted=972 rejected=1
# Person 973: accept=True | admitted=973 rejected=1
# Person 974: accept=True | admitted=974 rejected=1
# Person 975: accept=True | admitted=975 rejected=1
# Person 976: accept=True | admitted=976 rejected=1
# Person 977: accept=True | admitted=977 rejected=1
# Person 978: accept=True | admitted=978 rejected=1
# Person 979: accept=True | admitted=979 rejected=1
# Person 980: accept=True | admitted=980 rejected=1
# Person 981: accept=True | admitted=981 rejected=1
# Person 982: accept=True | admitted=982 rejected=1
# Person 983: accept=True | admitted=983 rejected=1
# Person 984: accept=True | admitted=984 rejected=1
# Person 985: accept=True | admitted=985 rejected=1
# Person 986: accept=True | admitted=986 rejected=1
# Person 987: accept=True | admitted=987 rejected=1
# Person 988: accept=True | admitted=988 rejected=1
# Person 989: accept=True | admitted=989 rejected=1
# Person 990: accept=True | admitted=990 rejected=1
# Person 991: accept=True | admitted=991 rejected=1
# Person 992: accept=True | admitted=992 rejected=1
# Person 993: accept=True | admitted=993 rejected=1
# Person 994: accept=True | admitted=994 rejected=1
# Person 995: accept=True | admitted=995 rejected=1
# Person 996: accept=True | admitted=996 rejected=1
# Person 997: accept=True | admitted=997 rejected=1
# Person 998: accept=True | admitted=998 rejected=1
# Person 999: accept=True | admitted=999 rejected=1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 8
#       6 status = state.get("status")
#       7 if status == "failed":
# ----> 8     raise RuntimeError(f"Game failed: {state.get('reason')}")
#      10 admitted = state.get("admittedCount", admitted)
#      11 rejected = state.get("rejectedCount", rejected)
#
# RuntimeError: Game failed: Venue full but constraints not met: techno_lover: 633/650 (need 17 more), creative: 75/300 (need 225 more), berlin_local: 406/750 (need 344 more)
