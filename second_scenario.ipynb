# %%
import requests
import random
from typing import Dict, Any, Optional


BASE_URL = "https://berghain.challenges.listenlabs.ai/"  # ← replace with the real host
PLAYER_ID = "5d7389b8-683e-453b-a35f-6d21b1b5e94e"
SCENARIO = 2  # choose 1, 2, or 3

def create_new_game(scenario: int, player_id: str) -> Dict[str, Any]:
    url = f"{BASE_URL}/new-game"
    res = requests.get(url, params={"scenario": scenario, "playerId": player_id}, timeout=30)
    res.raise_for_status()
    data = res.json()
    print("New game:", data["gameId"])
    return data


def decide_and_next(game_id: str, person_index: int, accept: Optional[bool] = None) -> Dict[str, Any]:
    url = f"{BASE_URL}/decide-and-next"
    params = {"gameId": game_id, "personIndex": person_index}
    if accept is not None:
        params["accept"] = str(accept).lower()  # true/false in query string
    res = requests.get(url, params=params, timeout=30)
    res.raise_for_status()
    return res.json()

new_game = create_new_game(SCENARIO, PLAYER_ID)
game_id = new_game["gameId"]
constraints = new_game.get("constraints", [])
stats = new_game.get("attributeStatistics", {})

print(constraints)
print(stats)
# Out:
# New game: 04f514ac-6428-4536-a2e3-d5bc46335262
# [{'attribute': 'techno_lover', 'minCount': 650}, {'attribute': 'well_connected', 'minCount': 450}, {'attribute': 'creative', 'minCount': 300}, {'attribute': 'berlin_local', 'minCount': 750}]
# {'relativeFrequencies': {'techno_lover': 0.6265000000000001, 'well_connected': 0.4700000000000001, 'creative': 0.06227, 'berlin_local': 0.398}, 'correlations': {'techno_lover': {'techno_lover': 1, 'well_connected': -0.4696169332674324, 'creative': 0.09463317039891586, 'berlin_local': -0.6549403815606182}, 'well_connected': {'techno_lover': -0.4696169332674324, 'well_connected': 1, 'creative': 0.14197259140471485, 'berlin_local': 0.5724067808436452}, 'creative': {'techno_lover': 0.09463317039891586, 'well_connected': 0.14197259140471485, 'creative': 1, 'berlin_local': 0.14446459505650772}, 'berlin_local': {'techno_lover': -0.6549403815606182, 'well_connected': 0.5724067808436452, 'creative': 0.14446459505650772, 'berlin_local': 1}}}

# %%
state = decide_and_next(game_id, person_index=0)
if state.get("status") == "failed":
    raise RuntimeError(f"Game failed: {state.get('reason')}")
admitted = state.get("admittedCount", 0)
rejected = state.get("rejectedCount", 0)
next_person = state.get("nextPerson")
total_ct = 0
total_wcb = 0
total_b = 0
total_t = 0
total_c = 0
total_wc = 0
n_accepted = 0
while state.get("status") == "running" and next_person:
        idx = next_person["personIndex"]
        attrs = next_person["attributes"]  # { attributeId: bool }
        t, wc, c, b = attrs.get("techno_lover", False), attrs.get("well_connected", False), attrs.get("creative", False), attrs.get("berlin_local", False)
        if b and t:
            accept = True        
        elif c and t:
            if total_ct < 250 or total_c < 300:
                accept = True
                total_ct += 1
        elif b and wc:
            if total_wcb < 350 and total_wc < 450:
                accept = True
                total_wcb += 1
        elif total_t < 650 and total_b >= 750:
            if t: accept = True
        elif total_t >= 650 and total_b < 750:
            if b: accept = True
        else:
            accept = False
        if accept:
            total_b += b
            total_t += t
            total_c += c
            total_wc += wc
            n_accepted += 1
        state = decide_and_next(game_id, person_index=idx, accept=accept)
        status = state.get("status")
        if status == "failed":
            raise RuntimeError(f"Game failed: {state.get('reason')}")

        admitted = state.get("admittedCount", admitted)
        rejected = state.get("rejectedCount", rejected)
        next_person = state.get("nextPerson")

        print(f"Person {idx}: accept={accept} | admitted={admitted} rejected={rejected}")

        # 5) done
if state.get("status") == "completed":
        print("Game completed.")
        print("Final rejected count:", state.get("rejectedCount"))
else:
        print("Game ended with state:", state)
# Out:
# Person 0: accept=False | admitted=0 rejected=1
# Person 1: accept=True | admitted=1 rejected=1
# Person 2: accept=False | admitted=1 rejected=2
# Person 3: accept=False | admitted=1 rejected=3
# Person 4: accept=False | admitted=1 rejected=4
# Person 5: accept=True | admitted=2 rejected=4
# Person 6: accept=False | admitted=2 rejected=5
# Person 7: accept=True | admitted=3 rejected=5
# Person 8: accept=True | admitted=4 rejected=5
# Person 9: accept=True | admitted=5 rejected=5
# Person 10: accept=False | admitted=5 rejected=6
# Person 11: accept=True | admitted=6 rejected=6
# Person 12: accept=False | admitted=6 rejected=7
# Person 13: accept=True | admitted=7 rejected=7
# Person 14: accept=True | admitted=8 rejected=7
# Person 15: accept=False | admitted=8 rejected=8
# Person 16: accept=False | admitted=8 rejected=9
# Person 17: accept=True | admitted=9 rejected=9
# Person 18: accept=False | admitted=9 rejected=10
# Person 19: accept=False | admitted=9 rejected=11
# Person 20: accept=False | admitted=9 rejected=12
# Person 21: accept=False | admitted=9 rejected=13
# Person 22: accept=False | admitted=9 rejected=14
# Person 23: accept=False | admitted=9 rejected=15
# Person 24: accept=True | admitted=10 rejected=15
# Person 25: accept=False | admitted=10 rejected=16
# Person 26: accept=True | admitted=11 rejected=16
# Person 27: accept=False | admitted=11 rejected=17
# Person 28: accept=False | admitted=11 rejected=18
# Person 29: accept=False | admitted=11 rejected=19
# Person 30: accept=False | admitted=11 rejected=20
# Person 31: accept=False | admitted=11 rejected=21
# Person 32: accept=False | admitted=11 rejected=22
# Person 33: accept=False | admitted=11 rejected=23
# Person 34: accept=False | admitted=11 rejected=24
# Person 35: accept=False | admitted=11 rejected=25
# Person 36: accept=True | admitted=12 rejected=25
# Person 37: accept=False | admitted=12 rejected=26
# Person 38: accept=True | admitted=13 rejected=26
# Person 39: accept=False | admitted=13 rejected=27
# Person 40: accept=False | admitted=13 rejected=28
# Person 41: accept=False | admitted=13 rejected=29
# Person 42: accept=False | admitted=13 rejected=30
# Person 43: accept=False | admitted=13 rejected=31
# Person 44: accept=False | admitted=13 rejected=32
# Person 45: accept=False | admitted=13 rejected=33
# Person 46: accept=True | admitted=14 rejected=33
# Person 47: accept=False | admitted=14 rejected=34
# Person 48: accept=True | admitted=15 rejected=34
# Person 49: accept=False | admitted=15 rejected=35
# Person 50: accept=True | admitted=16 rejected=35
# Person 51: accept=False | admitted=16 rejected=36
# Person 52: accept=False | admitted=16 rejected=37
# Person 53: accept=False | admitted=16 rejected=38
# Person 54: accept=False | admitted=16 rejected=39
# Person 55: accept=False | admitted=16 rejected=40
# Person 56: accept=False | admitted=16 rejected=41
# Person 57: accept=False | admitted=16 rejected=42
# Person 58: accept=False | admitted=16 rejected=43
# Person 59: accept=False | admitted=16 rejected=44
# Person 60: accept=True | admitted=17 rejected=44
# Person 61: accept=False | admitted=17 rejected=45
# Person 62: accept=False | admitted=17 rejected=46
# Person 63: accept=False | admitted=17 rejected=47
# Person 64: accept=False | admitted=17 rejected=48
# Person 65: accept=False | admitted=17 rejected=49
# Person 66: accept=False | admitted=17 rejected=50
# Person 67: accept=False | admitted=17 rejected=51
# Person 68: accept=False | admitted=17 rejected=52
# Person 69: accept=True | admitted=18 rejected=52
# Person 70: accept=False | admitted=18 rejected=53
# Person 71: accept=True | admitted=19 rejected=53
# Person 72: accept=True | admitted=20 rejected=53
# Person 73: accept=False | admitted=20 rejected=54
# Person 74: accept=False | admitted=20 rejected=55
# Person 75: accept=False | admitted=20 rejected=56
# Person 76: accept=False | admitted=20 rejected=57
# Person 77: accept=True | admitted=21 rejected=57
# Person 78: accept=True | admitted=22 rejected=57
# Person 79: accept=True | admitted=23 rejected=57
# Person 80: accept=False | admitted=23 rejected=58
# Person 81: accept=False | admitted=23 rejected=59
# Person 82: accept=False | admitted=23 rejected=60
# Person 83: accept=True | admitted=24 rejected=60
# Person 84: accept=False | admitted=24 rejected=61
# Person 85: accept=False | admitted=24 rejected=62
# Person 86: accept=False | admitted=24 rejected=63
# Person 87: accept=False | admitted=24 rejected=64
# Person 88: accept=False | admitted=24 rejected=65
# Person 89: accept=False | admitted=24 rejected=66
# Person 90: accept=True | admitted=25 rejected=66
# Person 91: accept=False | admitted=25 rejected=67
# Person 92: accept=False | admitted=25 rejected=68
# Person 93: accept=False | admitted=25 rejected=69
# Person 94: accept=False | admitted=25 rejected=70
# Person 95: accept=False | admitted=25 rejected=71
# Person 96: accept=True | admitted=26 rejected=71
# Person 97: accept=False | admitted=26 rejected=72
# Person 98: accept=True | admitted=27 rejected=72
# Person 99: accept=False | admitted=27 rejected=73
# Person 100: accept=False | admitted=27 rejected=74
# Person 101: accept=True | admitted=28 rejected=74
# Person 102: accept=True | admitted=29 rejected=74
# Person 103: accept=False | admitted=29 rejected=75
# Person 104: accept=False | admitted=29 rejected=76
# Person 105: accept=False | admitted=29 rejected=77
# Person 106: accept=False | admitted=29 rejected=78
# Person 107: accept=False | admitted=29 rejected=79
# Person 108: accept=True | admitted=30 rejected=79
# Person 109: accept=False | admitted=30 rejected=80
# Person 110: accept=False | admitted=30 rejected=81
# Person 111: accept=True | admitted=31 rejected=81
# Person 112: accept=True | admitted=32 rejected=81
# Person 113: accept=False | admitted=32 rejected=82
# Person 114: accept=False | admitted=32 rejected=83
# Person 115: accept=True | admitted=33 rejected=83
# Person 116: accept=False | admitted=33 rejected=84
# Person 117: accept=False | admitted=33 rejected=85
# Person 118: accept=True | admitted=34 rejected=85
# Person 119: accept=True | admitted=35 rejected=85
# Person 120: accept=False | admitted=35 rejected=86
# Person 121: accept=True | admitted=36 rejected=86
# Person 122: accept=False | admitted=36 rejected=87
# Person 123: accept=True | admitted=37 rejected=87
# Person 124: accept=True | admitted=38 rejected=87
# Person 125: accept=True | admitted=39 rejected=87
# Person 126: accept=False | admitted=39 rejected=88
# Person 127: accept=False | admitted=39 rejected=89
# Person 128: accept=True | admitted=40 rejected=89
# Person 129: accept=False | admitted=40 rejected=90
# Person 130: accept=True | admitted=41 rejected=90
# Person 131: accept=False | admitted=41 rejected=91
# Person 132: accept=False | admitted=41 rejected=92
# Person 133: accept=True | admitted=42 rejected=92
# Person 134: accept=False | admitted=42 rejected=93
# Person 135: accept=True | admitted=43 rejected=93
# Person 136: accept=True | admitted=44 rejected=93
# Person 137: accept=True | admitted=45 rejected=93
# Person 138: accept=True | admitted=46 rejected=93
# Person 139: accept=True | admitted=47 rejected=93
# Person 140: accept=False | admitted=47 rejected=94
# Person 141: accept=False | admitted=47 rejected=95
# Person 142: accept=False | admitted=47 rejected=96
# Person 143: accept=True | admitted=48 rejected=96
# Person 144: accept=False | admitted=48 rejected=97
# Person 145: accept=False | admitted=48 rejected=98
# Person 146: accept=True | admitted=49 rejected=98
# Person 147: accept=False | admitted=49 rejected=99
# Person 148: accept=True | admitted=50 rejected=99
# Person 149: accept=False | admitted=50 rejected=100
# Person 150: accept=True | admitted=51 rejected=100
# Person 151: accept=False | admitted=51 rejected=101
# Person 152: accept=True | admitted=52 rejected=101
# Person 153: accept=True | admitted=53 rejected=101
# Person 154: accept=False | admitted=53 rejected=102
# Person 155: accept=True | admitted=54 rejected=102
# Person 156: accept=False | admitted=54 rejected=103
# Person 157: accept=True | admitted=55 rejected=103
# Person 158: accept=True | admitted=56 rejected=103
# Person 159: accept=False | admitted=56 rejected=104
# Person 160: accept=False | admitted=56 rejected=105
# Person 161: accept=False | admitted=56 rejected=106
# Person 162: accept=False | admitted=56 rejected=107
# Person 163: accept=False | admitted=56 rejected=108
# Person 164: accept=False | admitted=56 rejected=109
# Person 165: accept=True | admitted=57 rejected=109
# Person 166: accept=False | admitted=57 rejected=110
# Person 167: accept=False | admitted=57 rejected=111
# Person 168: accept=False | admitted=57 rejected=112
# Person 169: accept=True | admitted=58 rejected=112
# Person 170: accept=False | admitted=58 rejected=113
# Person 171: accept=False | admitted=58 rejected=114
# Person 172: accept=False | admitted=58 rejected=115
# Person 173: accept=False | admitted=58 rejected=116
# Person 174: accept=False | admitted=58 rejected=117
# Person 175: accept=True | admitted=59 rejected=117
# Person 176: accept=True | admitted=60 rejected=117
# Person 177: accept=True | admitted=61 rejected=117
# Person 178: accept=True | admitted=62 rejected=117
# Person 179: accept=False | admitted=62 rejected=118
# Person 180: accept=True | admitted=63 rejected=118
# Person 181: accept=False | admitted=63 rejected=119
# Person 182: accept=False | admitted=63 rejected=120
# Person 183: accept=False | admitted=63 rejected=121
# Person 184: accept=False | admitted=63 rejected=122
# Person 185: accept=False | admitted=63 rejected=123
# Person 186: accept=True | admitted=64 rejected=123
# Person 187: accept=True | admitted=65 rejected=123
# Person 188: accept=False | admitted=65 rejected=124
# Person 189: accept=True | admitted=66 rejected=124
# Person 190: accept=False | admitted=66 rejected=125
# Person 191: accept=False | admitted=66 rejected=126
# Person 192: accept=True | admitted=67 rejected=126
# Person 193: accept=False | admitted=67 rejected=127
# Person 194: accept=False | admitted=67 rejected=128
# Person 195: accept=True | admitted=68 rejected=128
# Person 196: accept=False | admitted=68 rejected=129
# Person 197: accept=False | admitted=68 rejected=130
# Person 198: accept=False | admitted=68 rejected=131
# Person 199: accept=True | admitted=69 rejected=131
# Person 200: accept=False | admitted=69 rejected=132
# Person 201: accept=False | admitted=69 rejected=133
# Person 202: accept=False | admitted=69 rejected=134
# Person 203: accept=False | admitted=69 rejected=135
# Person 204: accept=False | admitted=69 rejected=136
# Person 205: accept=False | admitted=69 rejected=137
# Person 206: accept=False | admitted=69 rejected=138
# Person 207: accept=False | admitted=69 rejected=139
# Person 208: accept=False | admitted=69 rejected=140
# Person 209: accept=False | admitted=69 rejected=141
# Person 210: accept=False | admitted=69 rejected=142
# Person 211: accept=False | admitted=69 rejected=143
# Person 212: accept=False | admitted=69 rejected=144
# Person 213: accept=False | admitted=69 rejected=145
# Person 214: accept=False | admitted=69 rejected=146
# Person 215: accept=True | admitted=70 rejected=146
# Person 216: accept=False | admitted=70 rejected=147
# Person 217: accept=False | admitted=70 rejected=148
# Person 218: accept=True | admitted=71 rejected=148
# Person 219: accept=False | admitted=71 rejected=149
# Person 220: accept=True | admitted=72 rejected=149
# Person 221: accept=False | admitted=72 rejected=150
# Person 222: accept=False | admitted=72 rejected=151
# Person 223: accept=True | admitted=73 rejected=151
# Person 224: accept=False | admitted=73 rejected=152
# Person 225: accept=False | admitted=73 rejected=153
# Person 226: accept=True | admitted=74 rejected=153
# Person 227: accept=True | admitted=75 rejected=153
# Person 228: accept=False | admitted=75 rejected=154
# Person 229: accept=False | admitted=75 rejected=155
# Person 230: accept=False | admitted=75 rejected=156
# Person 231: accept=True | admitted=76 rejected=156
# Person 232: accept=True | admitted=77 rejected=156
# Person 233: accept=True | admitted=78 rejected=156
# Person 234: accept=False | admitted=78 rejected=157
# Person 235: accept=False | admitted=78 rejected=158
# Person 236: accept=True | admitted=79 rejected=158
# Person 237: accept=True | admitted=80 rejected=158
# Person 238: accept=True | admitted=81 rejected=158
# Person 239: accept=True | admitted=82 rejected=158
# Person 240: accept=True | admitted=83 rejected=158
# Person 241: accept=True | admitted=84 rejected=158
# Person 242: accept=True | admitted=85 rejected=158
# Person 243: accept=True | admitted=86 rejected=158
# Person 244: accept=False | admitted=86 rejected=159
# Person 245: accept=False | admitted=86 rejected=160
# Person 246: accept=False | admitted=86 rejected=161
# Person 247: accept=False | admitted=86 rejected=162
# Person 248: accept=False | admitted=86 rejected=163
# Person 249: accept=False | admitted=86 rejected=164
# Person 250: accept=True | admitted=87 rejected=164
# Person 251: accept=False | admitted=87 rejected=165
# Person 252: accept=False | admitted=87 rejected=166
# Person 253: accept=True | admitted=88 rejected=166
# Person 254: accept=False | admitted=88 rejected=167
# Person 255: accept=False | admitted=88 rejected=168
# Person 256: accept=True | admitted=89 rejected=168
# Person 257: accept=False | admitted=89 rejected=169
# Person 258: accept=True | admitted=90 rejected=169
# Person 259: accept=True | admitted=91 rejected=169
# Person 260: accept=False | admitted=91 rejected=170
# Person 261: accept=False | admitted=91 rejected=171
# Person 262: accept=False | admitted=91 rejected=172
# Person 263: accept=False | admitted=91 rejected=173
# Person 264: accept=False | admitted=91 rejected=174
# Person 265: accept=True | admitted=92 rejected=174
# Person 266: accept=False | admitted=92 rejected=175
# Person 267: accept=False | admitted=92 rejected=176
# Person 268: accept=True | admitted=93 rejected=176
# Person 269: accept=True | admitted=94 rejected=176
# Person 270: accept=False | admitted=94 rejected=177
# Person 271: accept=False | admitted=94 rejected=178
# Person 272: accept=False | admitted=94 rejected=179
# Person 273: accept=True | admitted=95 rejected=179
# Person 274: accept=False | admitted=95 rejected=180
# Person 275: accept=False | admitted=95 rejected=181
# Person 276: accept=False | admitted=95 rejected=182
# Person 277: accept=True | admitted=96 rejected=182
# Person 278: accept=True | admitted=97 rejected=182
# Person 279: accept=False | admitted=97 rejected=183
# Person 280: accept=False | admitted=97 rejected=184
# Person 281: accept=True | admitted=98 rejected=184
# Person 282: accept=False | admitted=98 rejected=185
# Person 283: accept=True | admitted=99 rejected=185
# Person 284: accept=False | admitted=99 rejected=186
# Person 285: accept=True | admitted=100 rejected=186
# Person 286: accept=True | admitted=101 rejected=186
# Person 287: accept=False | admitted=101 rejected=187
# Person 288: accept=False | admitted=101 rejected=188
# Person 289: accept=False | admitted=101 rejected=189
# Person 290: accept=False | admitted=101 rejected=190
# Person 291: accept=True | admitted=102 rejected=190
# Person 292: accept=False | admitted=102 rejected=191
# Person 293: accept=False | admitted=102 rejected=192
# Person 294: accept=True | admitted=103 rejected=192
# Person 295: accept=False | admitted=103 rejected=193
# Person 296: accept=False | admitted=103 rejected=194
# Person 297: accept=False | admitted=103 rejected=195
# Person 298: accept=False | admitted=103 rejected=196
# Person 299: accept=True | admitted=104 rejected=196
# Person 300: accept=True | admitted=105 rejected=196
# Person 301: accept=False | admitted=105 rejected=197
# Person 302: accept=True | admitted=106 rejected=197
# Person 303: accept=True | admitted=107 rejected=197
# Person 304: accept=False | admitted=107 rejected=198
# Person 305: accept=True | admitted=108 rejected=198
# Person 306: accept=True | admitted=109 rejected=198
# Person 307: accept=False | admitted=109 rejected=199
# Person 308: accept=False | admitted=109 rejected=200
# Person 309: accept=False | admitted=109 rejected=201
# Person 310: accept=True | admitted=110 rejected=201
# Person 311: accept=False | admitted=110 rejected=202
# Person 312: accept=True | admitted=111 rejected=202
# Person 313: accept=True | admitted=112 rejected=202
# Person 314: accept=False | admitted=112 rejected=203
# Person 315: accept=True | admitted=113 rejected=203
# Person 316: accept=False | admitted=113 rejected=204
# Person 317: accept=True | admitted=114 rejected=204
# Person 318: accept=True | admitted=115 rejected=204
# Person 319: accept=False | admitted=115 rejected=205
# Person 320: accept=False | admitted=115 rejected=206
# Person 321: accept=True | admitted=116 rejected=206
# Person 322: accept=False | admitted=116 rejected=207
# Person 323: accept=False | admitted=116 rejected=208
# Person 324: accept=False | admitted=116 rejected=209
# Person 325: accept=False | admitted=116 rejected=210
# Person 326: accept=False | admitted=116 rejected=211
# Person 327: accept=True | admitted=117 rejected=211
# Person 328: accept=False | admitted=117 rejected=212
# Person 329: accept=True | admitted=118 rejected=212
# Person 330: accept=False | admitted=118 rejected=213
# Person 331: accept=False | admitted=118 rejected=214
# Person 332: accept=False | admitted=118 rejected=215
# Person 333: accept=True | admitted=119 rejected=215
# Person 334: accept=True | admitted=120 rejected=215
# Person 335: accept=True | admitted=121 rejected=215
# Person 336: accept=True | admitted=122 rejected=215
# Person 337: accept=False | admitted=122 rejected=216
# Person 338: accept=True | admitted=123 rejected=216
# Person 339: accept=False | admitted=123 rejected=217
# Person 340: accept=False | admitted=123 rejected=218
# Person 341: accept=True | admitted=124 rejected=218
# Person 342: accept=False | admitted=124 rejected=219
# Person 343: accept=False | admitted=124 rejected=220
# Person 344: accept=False | admitted=124 rejected=221
# Person 345: accept=True | admitted=125 rejected=221
# Person 346: accept=True | admitted=126 rejected=221
# Person 347: accept=True | admitted=127 rejected=221
# Person 348: accept=True | admitted=128 rejected=221
# Person 349: accept=False | admitted=128 rejected=222
# Person 350: accept=True | admitted=129 rejected=222
# Person 351: accept=True | admitted=130 rejected=222
# Person 352: accept=False | admitted=130 rejected=223
# Person 353: accept=False | admitted=130 rejected=224
# Person 354: accept=True | admitted=131 rejected=224
# Person 355: accept=False | admitted=131 rejected=225
# Person 356: accept=True | admitted=132 rejected=225
# Person 357: accept=False | admitted=132 rejected=226
# Person 358: accept=True | admitted=133 rejected=226
# Person 359: accept=False | admitted=133 rejected=227
# Person 360: accept=False | admitted=133 rejected=228
# Person 361: accept=False | admitted=133 rejected=229
# Person 362: accept=True | admitted=134 rejected=229
# Person 363: accept=False | admitted=134 rejected=230
# Person 364: accept=True | admitted=135 rejected=230
# Person 365: accept=False | admitted=135 rejected=231
# Person 366: accept=False | admitted=135 rejected=232
# Person 367: accept=False | admitted=135 rejected=233
# Person 368: accept=False | admitted=135 rejected=234
# Person 369: accept=False | admitted=135 rejected=235
# Person 370: accept=False | admitted=135 rejected=236
# Person 371: accept=False | admitted=135 rejected=237
# Person 372: accept=True | admitted=136 rejected=237
# Person 373: accept=False | admitted=136 rejected=238
# Person 374: accept=False | admitted=136 rejected=239
# Person 375: accept=True | admitted=137 rejected=239
# Person 376: accept=True | admitted=138 rejected=239
# Person 377: accept=False | admitted=138 rejected=240
# Person 378: accept=True | admitted=139 rejected=240
# Person 379: accept=False | admitted=139 rejected=241
# Person 380: accept=True | admitted=140 rejected=241
# Person 381: accept=True | admitted=141 rejected=241
# Person 382: accept=False | admitted=141 rejected=242
# Person 383: accept=True | admitted=142 rejected=242
# Person 384: accept=False | admitted=142 rejected=243
# Person 385: accept=False | admitted=142 rejected=244
# Person 386: accept=True | admitted=143 rejected=244
# Person 387: accept=False | admitted=143 rejected=245
# Person 388: accept=True | admitted=144 rejected=245
# Person 389: accept=True | admitted=145 rejected=245
# Person 390: accept=True | admitted=146 rejected=245
# Person 391: accept=False | admitted=146 rejected=246
# Person 392: accept=False | admitted=146 rejected=247
# Person 393: accept=True | admitted=147 rejected=247
# Person 394: accept=True | admitted=148 rejected=247
# Person 395: accept=False | admitted=148 rejected=248
# Person 396: accept=False | admitted=148 rejected=249
# Person 397: accept=False | admitted=148 rejected=250
# Person 398: accept=True | admitted=149 rejected=250
# Person 399: accept=False | admitted=149 rejected=251
# Person 400: accept=True | admitted=150 rejected=251
# Person 401: accept=False | admitted=150 rejected=252
# Person 402: accept=True | admitted=151 rejected=252
# Person 403: accept=False | admitted=151 rejected=253
# Person 404: accept=False | admitted=151 rejected=254
# Person 405: accept=True | admitted=152 rejected=254
# Person 406: accept=False | admitted=152 rejected=255
# Person 407: accept=False | admitted=152 rejected=256
# Person 408: accept=False | admitted=152 rejected=257
# Person 409: accept=False | admitted=152 rejected=258
# Person 410: accept=True | admitted=153 rejected=258
# Person 411: accept=True | admitted=154 rejected=258
# Person 412: accept=False | admitted=154 rejected=259
# Person 413: accept=True | admitted=155 rejected=259
# Person 414: accept=False | admitted=155 rejected=260
# Person 415: accept=False | admitted=155 rejected=261
# Person 416: accept=False | admitted=155 rejected=262
# Person 417: accept=True | admitted=156 rejected=262
# Person 418: accept=True | admitted=157 rejected=262
# Person 419: accept=False | admitted=157 rejected=263
# Person 420: accept=True | admitted=158 rejected=263
# Person 421: accept=False | admitted=158 rejected=264
# Person 422: accept=True | admitted=159 rejected=264
# Person 423: accept=False | admitted=159 rejected=265
# Person 424: accept=False | admitted=159 rejected=266
# Person 425: accept=True | admitted=160 rejected=266
# Person 426: accept=False | admitted=160 rejected=267
# Person 427: accept=True | admitted=161 rejected=267
# Person 428: accept=True | admitted=162 rejected=267
# Person 429: accept=True | admitted=163 rejected=267
# Person 430: accept=False | admitted=163 rejected=268
# Person 431: accept=True | admitted=164 rejected=268
# Person 432: accept=False | admitted=164 rejected=269
# Person 433: accept=True | admitted=165 rejected=269
# Person 434: accept=False | admitted=165 rejected=270
# Person 435: accept=True | admitted=166 rejected=270
# Person 436: accept=True | admitted=167 rejected=270
# Person 437: accept=False | admitted=167 rejected=271
# Person 438: accept=False | admitted=167 rejected=272
# Person 439: accept=False | admitted=167 rejected=273
# Person 440: accept=False | admitted=167 rejected=274
# Person 441: accept=True | admitted=168 rejected=274
# Person 442: accept=False | admitted=168 rejected=275
# Person 443: accept=False | admitted=168 rejected=276
# Person 444: accept=True | admitted=169 rejected=276
# Person 445: accept=False | admitted=169 rejected=277
# Person 446: accept=True | admitted=170 rejected=277
# Person 447: accept=False | admitted=170 rejected=278
# Person 448: accept=False | admitted=170 rejected=279
# Person 449: accept=False | admitted=170 rejected=280
# Person 450: accept=False | admitted=170 rejected=281
# Person 451: accept=False | admitted=170 rejected=282
# Person 452: accept=False | admitted=170 rejected=283
# Person 453: accept=False | admitted=170 rejected=284
# Person 454: accept=False | admitted=170 rejected=285
# Person 455: accept=False | admitted=170 rejected=286
# Person 456: accept=False | admitted=170 rejected=287
# Person 457: accept=False | admitted=170 rejected=288
# Person 458: accept=False | admitted=170 rejected=289
# Person 459: accept=False | admitted=170 rejected=290
# Person 460: accept=False | admitted=170 rejected=291
# Person 461: accept=False | admitted=170 rejected=292
# Person 462: accept=True | admitted=171 rejected=292
# Person 463: accept=True | admitted=172 rejected=292
# Person 464: accept=False | admitted=172 rejected=293
# Person 465: accept=False | admitted=172 rejected=294
# Person 466: accept=True | admitted=173 rejected=294
# Person 467: accept=True | admitted=174 rejected=294
# Person 468: accept=True | admitted=175 rejected=294
# Person 469: accept=False | admitted=175 rejected=295
# Person 470: accept=True | admitted=176 rejected=295
# Person 471: accept=False | admitted=176 rejected=296
# Person 472: accept=False | admitted=176 rejected=297
# Person 473: accept=False | admitted=176 rejected=298
# Person 474: accept=False | admitted=176 rejected=299
# Person 475: accept=True | admitted=177 rejected=299
# Person 476: accept=True | admitted=178 rejected=299
# Person 477: accept=False | admitted=178 rejected=300
# Person 478: accept=True | admitted=179 rejected=300
# Person 479: accept=True | admitted=180 rejected=300
# Person 480: accept=True | admitted=181 rejected=300
# Person 481: accept=True | admitted=182 rejected=300
# Person 482: accept=False | admitted=182 rejected=301
# Person 483: accept=False | admitted=182 rejected=302
# Person 484: accept=False | admitted=182 rejected=303
# Person 485: accept=False | admitted=182 rejected=304
# Person 486: accept=False | admitted=182 rejected=305
# Person 487: accept=True | admitted=183 rejected=305
# Person 488: accept=False | admitted=183 rejected=306
# Person 489: accept=False | admitted=183 rejected=307
# Person 490: accept=False | admitted=183 rejected=308
# Person 491: accept=False | admitted=183 rejected=309
# Person 492: accept=True | admitted=184 rejected=309
# Person 493: accept=True | admitted=185 rejected=309
# Person 494: accept=True | admitted=186 rejected=309
# Person 495: accept=True | admitted=187 rejected=309
# Person 496: accept=False | admitted=187 rejected=310
# Person 497: accept=False | admitted=187 rejected=311
# Person 498: accept=False | admitted=187 rejected=312
# Person 499: accept=True | admitted=188 rejected=312
# Person 500: accept=True | admitted=189 rejected=312
# Person 501: accept=True | admitted=190 rejected=312
# Person 502: accept=True | admitted=191 rejected=312
# Person 503: accept=False | admitted=191 rejected=313
# Person 504: accept=False | admitted=191 rejected=314
# Person 505: accept=False | admitted=191 rejected=315
# Person 506: accept=True | admitted=192 rejected=315
# Person 507: accept=False | admitted=192 rejected=316
# Person 508: accept=False | admitted=192 rejected=317
# Person 509: accept=True | admitted=193 rejected=317
# Person 510: accept=True | admitted=194 rejected=317
# Person 511: accept=True | admitted=195 rejected=317
# Person 512: accept=False | admitted=195 rejected=318
# Person 513: accept=False | admitted=195 rejected=319
# Person 514: accept=True | admitted=196 rejected=319
# Person 515: accept=True | admitted=197 rejected=319
# Person 516: accept=True | admitted=198 rejected=319
# Person 517: accept=True | admitted=199 rejected=319
# Person 518: accept=False | admitted=199 rejected=320
# Person 519: accept=False | admitted=199 rejected=321
# Person 520: accept=False | admitted=199 rejected=322
# Person 521: accept=False | admitted=199 rejected=323
# Person 522: accept=False | admitted=199 rejected=324
# Person 523: accept=False | admitted=199 rejected=325
# Person 524: accept=True | admitted=200 rejected=325
# Person 525: accept=True | admitted=201 rejected=325
# Person 526: accept=False | admitted=201 rejected=326
# Person 527: accept=False | admitted=201 rejected=327
# Person 528: accept=True | admitted=202 rejected=327
# Person 529: accept=True | admitted=203 rejected=327
# Person 530: accept=False | admitted=203 rejected=328
# Person 531: accept=False | admitted=203 rejected=329
# Person 532: accept=False | admitted=203 rejected=330
# Person 533: accept=False | admitted=203 rejected=331
# Person 534: accept=False | admitted=203 rejected=332
# Person 535: accept=False | admitted=203 rejected=333
# Person 536: accept=False | admitted=203 rejected=334
# Person 537: accept=True | admitted=204 rejected=334
# Person 538: accept=True | admitted=205 rejected=334
# Person 539: accept=True | admitted=206 rejected=334
# Person 540: accept=False | admitted=206 rejected=335
# Person 541: accept=False | admitted=206 rejected=336
# Person 542: accept=False | admitted=206 rejected=337
# Person 543: accept=False | admitted=206 rejected=338
# Person 544: accept=False | admitted=206 rejected=339
# Person 545: accept=False | admitted=206 rejected=340
# Person 546: accept=False | admitted=206 rejected=341
# Person 547: accept=False | admitted=206 rejected=342
# Person 548: accept=False | admitted=206 rejected=343
# Person 549: accept=False | admitted=206 rejected=344
# Person 550: accept=False | admitted=206 rejected=345
# Person 551: accept=True | admitted=207 rejected=345
# Person 552: accept=True | admitted=208 rejected=345
# Person 553: accept=False | admitted=208 rejected=346
# Person 554: accept=False | admitted=208 rejected=347
# Person 555: accept=True | admitted=209 rejected=347
# Person 556: accept=True | admitted=210 rejected=347
# Person 557: accept=False | admitted=210 rejected=348
# Person 558: accept=False | admitted=210 rejected=349
# Person 559: accept=False | admitted=210 rejected=350
# Person 560: accept=True | admitted=211 rejected=350
# Person 561: accept=True | admitted=212 rejected=350
# Person 562: accept=True | admitted=213 rejected=350
# Person 563: accept=False | admitted=213 rejected=351
# Person 564: accept=True | admitted=214 rejected=351
# Person 565: accept=True | admitted=215 rejected=351
# Person 566: accept=False | admitted=215 rejected=352
# Person 567: accept=True | admitted=216 rejected=352
# Person 568: accept=False | admitted=216 rejected=353
# Person 569: accept=False | admitted=216 rejected=354
# Person 570: accept=True | admitted=217 rejected=354
# Person 571: accept=False | admitted=217 rejected=355
# Person 572: accept=True | admitted=218 rejected=355
# Person 573: accept=False | admitted=218 rejected=356
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[13], line 40
#      38     total_wc += wc
#      39     n_accepted += 1
# ---> 40 state = decide_and_next(game_id, person_index=idx, accept=accept)
#      41 status = state.get("status")
#      42 if status == "failed":
#
# Cell In[12], line 24, in decide_and_next(game_id, person_index, accept)
#      22 if accept is not None:
#      23     params["accept"] = str(accept).lower()  # true/false in query string
# ---> 24 res = requests.get(url, params=params, timeout=30)
#      25 res.raise_for_status()
#      26 return res.json()
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\axeld\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
